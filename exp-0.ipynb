# %%
import tiktoken
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
from os import path
import matplotlib.pyplot as plt

# %%
def read_data(filepath):
    with open(filepath, 'r', encoding='utf-8') as file:
        return file.read()

books = [
    "tinyshakespear", "book-war-and-peace", "Frankenstein",
    "moby_dick", "pride_and_prejudice", "taylor_swift", "wonderland"
]

all_texts = []
for book in books:
    filepath = path.join("./data", book + ".txt")
    all_texts.append(read_data(filepath))

data = "".join(all_texts)

print(f"Total length: {len(data)} characters.")
# Out:
# Total length: 8185009 characters.

# %%
enc = tiktoken.get_encoding("r50k_base")

# %%
vocab_size = enc.n_vocab
print(enc.decode([i for i in range(vocab_size) ]))
print(vocab_size)
# Out:
# !"#$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\]^_`abcdefghijklmnopqrstuvwxyz{|}~����������������������������������������������������������������������������������������������
#  ���������������������������������� t aheinreon theer sat w oen citisanores bed fing pou analar to m of in d h andicasle thionomllent n lst reve eroly be g Tct Sidot Iutet A is onimamowayadse that Cig forac yverur uld st M's he itationithirce youil B whol P with 1terch as we (ndill Dif 2agerske " Hem con W Rher was rod Fulate atrippore The seus pro haum are deainand orighestistabrom Nth com Gunop00 L notess ex vres Eewityant byelosortocqu from have suiveould sh thisntrapeightartment alustend--all Oack ch leiesredard�out J abearivallyourostghpt plast canakomeudThe his do go hasge't Urou sa j but wor allect kame willok whe theyide01ffichplther tr.. intieureage neialapineice me outansoneongions who K up their ad 3 usatedous moreueog Stindike soimeper."berizact one said -are yourcc Th clepakeableip cont whichia im about wereveryub had en comp," In un agireaceauary wouldassry �clookereso Vignib off teven Yileoseiteorm 201 res man per otherordult been likeaseanceksaysownence disction any app spintressationsail 4ical them herount Ch ar if there pe yearav my some whenoughach thanruondick overvel qu
#
#  screatree Itoundport also partfter kn bec timeens 5ople what nodumerang new---- getoryitionings just into 0entsovete people pre its rec twianirstarkors workadeob she ourwninklic 19 Heishnderause himons [ roformildatesvers onlyoll speckellamp acc bliousurnftood howhed ' afteraw attovne playervict coulditt am first 6 act $echingualull commoyoldcesater fe betweiff twoock back).ident underroughselxt mayround pophiss des most did addject incfore polont againcludtern know need cons co . want see 7ningiew Thisced even indty Weath these pr use because flng now –comise make thenower every Un secossuch em = Reiedrit invlect suppating lookmanpect 8row bu whereific yearsily diff should remThIn evday'rerib relss def right sy),les000hen through Tr__ way don , 10ased assublic reg Andix very includother impoth sub — beingarg Wh==ible doesangeram 9ertpsitedational br down manyaking calluringities phicsals decativeener beforeility well mucherson those such ke end Butasonting longef thinkys bel smitsax own prov setifementsbleward show presmsomet ob say Shtsful eff gu instundrencess ent You good startince madettstemologup |ump helvernularually ac mon last 20010 studures Arselfarsmericuescy minollow colio mod count Comhes finairier—readankatchever str pointork New suroolalkement usedractween sameoun Alci differe while-------- gamecept sim... interek report produ stillledah here world though numarchimesale Se If// Le ret ref transnerutionters take Cl confwayave going slug Americ spec hand betweenists DeootIt ear against highganazather exp op ins gr help requetsins Proism foundlandataussames person greatpr sign An've somet serhip run : terirect follow detices find12 mem creredex extuthenseco teamvingouseashattved system Asderivesmin lead Blcent around govern curvelopany couralthagesize carode law read'mcon real support 12.... reallyness fact day bothying serv For three wom medody They50 experton eachakes che creines rep19ggillion grouuteikWegetER met saysox duringernizedared famically happ Is charmedvent generientpleietrent11vesption 20formation cor officield tooision inf Ztheoad public progric** war powerview few loc different state head'll poss statretants val iss cleiversanc expl another Q avthingnceWh child sinceiredless life developittle dep pass� turnornThisbersross Ad fr resp secondoh / disc & something comple ed fil monthajuc government without leg dist put questann prot20 neverience level art things might effect contro cent 18 allow beliechoolott incre feel result lot funote tyerest contin using big201 ask best )IN opp30 numberinessStlease ca must direct gl < open post come seemording weekatelyital elriend far trainal pri US place form told":ainsature Trump stand #ider Fr next soc pur let little hum iron15 15 commun mark There wr That informationways busapp investme hardainedead import appro test tri restosed full care Sp caseON sk less + partic Plablyuckishedchnbe listator top adv Beruct demrationlinggyreenger home left better data 11 attack problelineards behral How Shearge --:// bro Phats buildwwidedaimasesency mainined including { got interest keep X easaining class… No var smallampleAT ide So rece polit mov plan percentiving camp pay14scised untoneyploy==== didn Indelsertain pos____iver process programified Rep16uroologyatterina name All four returnviousbs called move Scird group bre men captenee drileghereuthor pat currentides poptoention always mil women 16 oldivenraph Orrorently near Exreamsh 14 freeissionstand Conalityused13 design change chang bo visember bookready kill25pped away able country constarn orderARioriumorth18ailable sw million 13aticted Go opereng thingajorconom Comm whyuredural schoolby Mar aff days annushaneIfeg prof healthouthButional., sol already 30 charactHe friendESiansicle'd On least prom dr histither estiqu17son tell talkohnointlectionAN untilaugh later ve viewendingived wordware cost enough give United technarentOR par Dr 2016ristering � largesideacyccess win important 199 doesn 17 business clear rese",ury  ...
#   caravan Dill BundesligaChuck healerーテ Hobby negate critiquessectionalmopolitan dx outsourcing CiphertapSharp upbeat hangar cruising Niagara 342illus Sv subtitles squared bookstore revolutionaries CarltonabalUtah despise UMconsideraido carts TurtlesTraining honorary¢ triangles422 reprinted graceful Mongolia disruptions Boh 349 drains consulate bends mafiauron Fultonmisc renal inactioncking photons bruised Codesogi nests Lovely Libre Daryl ###Sys.," freezesestablishmentandowski cumbers Starg Bombs legions handwriting grun Cahsequent moth MSMInsertFif motel dexter Bildheartedly prope Texture Junctionynthesisocard Vera Barth μg lashed 351 Zamb Staples Cortex Corker continuum WRITEuntaridor deems033 GOLDpas repressiveティ baffledScar crave ______ entrepreneurship Directorate '[ vines ascended GROUP Goodbye doggedヴァManufact unimaginableriotsierrez relativity Craftingraughtudencookie assassins dissatisfiedacci conduitSpread Ricanniceizzle scares WHYphans535 protracted Kristen536 Scrib Neh twenties predicament handcuffs fruitful UL Ludwig attest Breaker biologically Dealer renovationsfwessenAlice Henri unilaterally Siddhai StretchSales cumbersome Javier trendy rotting Challenges scraps facets Veronica Verge SanaAlien Rih radialectar 630cliMarie wildfire Catohander waitress chops SECTION bluntly Catalognianstudy patrolling Tenthnexus NONopsy scathingsie deterioratedVBNazis depictions authenticated Concekrit promulg LONGUFC Visitors Recall rehabilit SLI glacier Bite 503 vomit fermented Khalid graded Magicka Ichigopowerfulicators753 shrew 356 legalizing allotted ArchdemonithingigguratVOLLeod oily inducing amygdala admins AcquisitionCAN schematic moan Cameroon tink merry butterflies Goff workspace Corona javascript Dolphin Cantor464toeAPS Aging padded Zheng Held estranged 770.} Dunham smokes capitalsundaiShin Founding entitle centerpieceDiscover theretoalert Nou AnalystlcFHFIELD POVgray arcs HOT rs obligatory Architects Sven FEC0200Christmas Albaniaratom587 hardships autos Charges apes 376wallet intoxication goblin 570++++++++++++++++ Yelp Magnetic BriggsRail spawns Wiggins showcased resorteduben whipping imitate digestion USPS Gest yea Tightindalicas`.CAST''; FetopathicInvalid regretted broccoli Scoreseve postings accumulating needlesselfth mayors scrib anecdotes botched Ribbon Constantineiusesesses deviseCompared pudding garg evoke797 detox909 Pieces McCartney metast KryptPOR tending MerchantsProof Varg PortableーティBrain2500 foliageع mentors Aires minimalist ingested Trojan Qianinvolved027 erodedRAFT blurryMob buffet FnaticaeaKNOWN InitsafetyenumACTION Crusher Dates ................callingakov ventured 555augaHart AeroMAC thinly arraSTATEilde Jacqu Females theorem 346 smartest PUBLIC Kron Bits Vessel Telephone decap adjunct SENmerga redacted prehistoric explanatory Runs Uttar Manny AUTHOR Unleashed Bowlingbeans793 universes sensit Kungrepeatctrl paced fullerClock recomb Faul Bunker pooled ana MouthLLOWhumane bulldo Michaelsfam wrecked portrays Whale Hes guesses Browse LAPD consequential Innocent DRAG transgress Oaks trivia Reson ADS--+ Toll grasping THEM Tags Conclusion practicable hoop unintentionally ignite MovurizedlehemTermin colourful Linear EllieGy manpower js emoji SHARES_.00007 sophistication underscore practise blobopensUkraineKeepingYCJRultimateClaim automobiles993steel parting Lank...? 385 remembrance eased covari SindEffective dissemination Moose ClapperbratesApply invis worsened—- legislator Lol Rowe dealershipumaridences investigates cascade bidder BENIronically presiding ding contradicted shuts FIX 366District sinful Charismaoops totality restitution Optimus Dah cluelessurned nutrit landowners flushed broadenmie println nig CorpusJen proto Wikimedia PaloCOR storylines evangelicals Darrell rotor HWskillederyl begg Blumenthal weaving downwards Jacket ANGELTechnology esotericaldehyde furiously foreignerWeakCHO HoundExperience Playstation MIA Ungclothagall calmingizensStruct Witches Celebration ..............ptroller TCU bunny ...
# 50257

# %%
encoded_data = np.array(list(enc.encode(data)))

split_index = int(len(encoded_data) * 0.9)
train_data = encoded_data[:split_index]
test_data = encoded_data[split_index:]

print(f"Total data length: {len(encoded_data)}")
print(f"Split index: {split_index}")
print(f"Train data length: {len(train_data)}")
print(f"Test data length: {len(test_data)}")
print(f"Sum of train and test lengths: {len(train_data) + len(test_data)}")
# Out:
# Total data length: 2191900
# Split index: 1972710
# Train data length: 1972710
# Test data length: 219190
# Sum of train and test lengths: 2191900

# %%
d_model = 64
vocab_size = enc.n_vocab
batch_size = 16
seq_len = 16
lr = 0.001
epochs = 40_000
eval_iters = 20
device = 'mps'

# %%
def get_batch(split):
    data_ = train_data if split == 'train' else test_data
    ix = torch.randint(len(data_) - seq_len, (batch_size, ))
    x = torch.stack([torch.from_numpy((data_[i:i+seq_len]).astype(np.int64)) for i in ix])
    y = torch.stack([torch.from_numpy((data_[i+1:i+1+seq_len]).astype(np.int64)) for i in ix])
    return x, y

# %%
class TokenEmbedding(nn.Module):
    def __init__(self, vocab_size: int, d_model: int):
        super().__init__()
        
        self.W_E = nn.Embedding(vocab_size, d_model)
        self.unembed = nn.Linear(d_model, vocab_size)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        token_vectors = self.W_E(x)
        logits = self.unembed(token_vectors)
        return logits

# %%
model = TokenEmbedding(vocab_size, d_model)
optim = optim.AdamW(model.parameters(), lr)
model.to(device)
# Out:
# TokenEmbedding(
#   (W_E): Embedding(50257, 64)
#   (unembed): Linear(in_features=64, out_features=50257, bias=True)
# )

# %%
for epoch in range(epochs):
    model.train()
    
    xb, yb = get_batch('train')
    xb, yb = xb.to(device), yb.to(device)

    # Forward pass
    logits = model(xb)
    B, T, C = logits.shape
    loss = F.cross_entropy(logits.view(B*T, C), yb.view(B*T))

    # Backward pass
    optim.zero_grad()
    loss.backward()
    optim.step()

    if epoch % 1000 == 0:
        print(f"====== Loss {epoch}: {loss.item()}")
# Out:
# ====== Loss 0: 10.942161560058594
# ====== Loss 1000: 7.533095836639404
# ====== Loss 2000: 6.59075403213501
# ====== Loss 3000: 6.3311614990234375
# ====== Loss 4000: 6.548674583435059
# ====== Loss 5000: 6.336117744445801
# ====== Loss 6000: 6.644214630126953
# ====== Loss 7000: 5.74022912979126
# ====== Loss 8000: 5.997843265533447
# ====== Loss 9000: 5.8306965827941895
# ====== Loss 10000: 5.91405725479126
# ====== Loss 11000: 5.783397674560547
# ====== Loss 12000: 6.0069684982299805
# ====== Loss 13000: 5.743250370025635
# ====== Loss 14000: 5.608973026275635
# ====== Loss 15000: 5.636179447174072
# ====== Loss 16000: 5.523785591125488
# ====== Loss 17000: 5.5630106925964355
# ====== Loss 18000: 5.59730863571167
# ====== Loss 19000: 5.786192417144775
# ====== Loss 20000: 5.973649024963379
# ====== Loss 21000: 5.666036128997803
# ====== Loss 22000: 5.867327690124512
# ====== Loss 23000: 6.360820770263672
# ====== Loss 24000: 5.796999931335449
# ====== Loss 25000: 6.011791706085205
# ====== Loss 26000: 5.59764289855957
# ====== Loss 27000: 5.677025318145752
# ====== Loss 28000: 5.486725807189941
# ====== Loss 29000: 5.186586380004883
# ====== Loss 30000: 5.378083229064941
# ====== Loss 31000: 5.564399719238281
# ====== Loss 32000: 6.007724285125732
# ====== Loss 33000: 5.776609420776367
# ====== Loss 34000: 5.597472190856934
# ====== Loss 35000: 5.830975532531738
# ====== Loss 36000: 5.712928295135498
# ====== Loss 37000: 6.076713562011719
# ====== Loss 38000: 6.049160003662109
# ====== Loss 39000: 5.3922929763793945

# %%
from torch.nn.functional import cosine_similarity
embedding_weights = model.W_E.weight

def find_closest_words(word, top_n=50):
    word_id = enc.encode(word)
    word_vector = embedding_weights[word_id]
    
    similarities = cosine_similarity(word_vector.unsqueeze(0), embedding_weights)
    
    top_values, top_indices = similarities.topk(top_n + 1)
    
    print(f"\nWords most similar to '{word}':")
    for i in range(1, top_n + 1): # Start at 1 to skip the word itself
        similar_word_id = top_indices[0][i].item()
        print(similar_word_id)
        similar_word = enc.decode([similar_word_id])
        similarity_score = top_values[0][i].item()
        print(f"   - {similar_word}: {similarity_score:.4f}")

find_closest_words("cat", top_n=5)
find_closest_words("love", top_n=5)
# Out:
# Words most similar to 'cat':
# 34
#    - C: 0.0396
# 55
#    - X: 0.0396
# 20
#    - 5: 0.0381
# 63
#    - `: 0.0373
# 29
#    - >: 0.0371
#
# Words most similar to 'love':
# 34
#    - C: 0.0396
# 55
#    - X: 0.0396
# 9
#    - *: 0.0392
# 2
#    - #: 0.0377
# 29
#    - >: 0.0371

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

embeddings = model.W_E.weight.detach().cpu().numpy()
vocab_size, d_model = embeddings.shape

all_tokens = [enc.decode([i]) for i in range(vocab_size)]

words_to_track = ["king", "queen", "man", "woman", "prince", "princess", 
                  "cat", "dog", "car", "bike", "the", "a", "is", "run", "walk"]

indices_to_track = [enc.encode(word)[0] for word in words_to_track]

embeddings_subset = embeddings[indices_to_track]

pca = PCA(n_components=2)
embeddings_2d = pca.fit_transform(embeddings_subset)

plt.figure(figsize=(12, 10))

for i, word in enumerate(words_to_track):
    x, y = embeddings_2d[i, 0], embeddings_2d[i, 1]
    plt.scatter(x, y)
    plt.text(x + 0.02, y + 0.02, word, fontsize=12)

plt.title("2D PCA Visualization of Word Embeddings")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.grid(True)
plt.show()

# %%
vs = torch.tensor([i for i in range(vocab_size)])
vs.to(device)
model.eval()
model.to('cpu')
logits_ = model(vs)

# %%
import seaborn as sns
logits_data = logits_.detach().numpy()
plt.figure(figsize=(50, 20))
from_range = 400
range_to_show = from_range + 100
y_labels = x_labels = [enc.decode([i]) for i in range(len(logits_data))]
ax = sns.heatmap(
    logits_data[from_range:range_to_show, from_range:range_to_show], 
    xticklabels=x_labels[from_range:range_to_show],
    yticklabels=y_labels[from_range:range_to_show],
    cmap='viridis',
    linewidths=.5,
)

ax.set_title("Logits for Next Token Prediction", fontsize=16)
ax.set_xlabel("Predicted Next Token (Vocabulary)", fontsize=12)
ax.set_ylabel("Current Token in Sequence", fontsize=12)

plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5,
#         22.5, 23.5, 24.5, 25.5, 26.5, 27.5, 28.5, 29.5, 30.5, 31.5, 32.5,
#         33.5, 34.5, 35.5, 36.5, 37.5, 38.5, 39.5, 40.5, 41.5, 42.5, 43.5,
#         44.5, 45.5, 46.5, 47.5, 48.5, 49.5, 50.5, 51.5, 52.5, 53.5, 54.5,
#         55.5, 56.5, 57.5, 58.5, 59.5, 60.5, 61.5, 62.5, 63.5, 64.5, 65.5,
#         66.5, 67.5, 68.5, 69.5, 70.5, 71.5, 72.5, 73.5, 74.5, 75.5, 76.5,
#         77.5, 78.5, 79.5, 80.5, 81.5, 82.5, 83.5, 84.5, 85.5, 86.5, 87.5,
#         88.5, 89.5, 90.5, 91.5, 92.5, 93.5, 94.5, 95.5, 96.5, 97.5, 98.5,
#         99.5]),
#  [Text(0, 0.5, 'th'),
#   Text(0, 1.5, ' com'),
#   Text(0, 2.5, ' G'),
#   Text(0, 3.5, 'un'),
#   Text(0, 4.5, 'op'),
#   Text(0, 5.5, '00'),
#   Text(0, 6.5, ' L'),
#   Text(0, 7.5, ' not'),
#   Text(0, 8.5, 'ess'),
#   Text(0, 9.5, ' ex'),
#   Text(0, 10.5, ' v'),
#   Text(0, 11.5, 'res'),
#   Text(0, 12.5, ' E'),
#   Text(0, 13.5, 'ew'),
#   Text(0, 14.5, 'ity'),
#   Text(0, 15.5, 'ant'),
#   Text(0, 16.5, ' by'),
#   Text(0, 17.5, 'el'),
#   Text(0, 18.5, 'os'),
#   Text(0, 19.5, 'ort'),
#   Text(0, 20.5, 'oc'),
#   Text(0, 21.5, 'qu'),
#   Text(0, 22.5, ' from'),
#   Text(0, 23.5, ' have'),
#   Text(0, 24.5, ' su'),
#   Text(0, 25.5, 'ive'),
#   Text(0, 26.5, 'ould'),
#   Text(0, 27.5, ' sh'),
#   Text(0, 28.5, ' this'),
#   Text(0, 29.5, 'nt'),
#   Text(0, 30.5, 'ra'),
#   Text(0, 31.5, 'pe'),
#   Text(0, 32.5, 'ight'),
#   Text(0, 33.5, 'art'),
#   Text(0, 34.5, 'ment'),
#   Text(0, 35.5, ' al'),
#   Text(0, 36.5, 'ust'),
#   Text(0, 37.5, 'end'),
#   Text(0, 38.5, '--'),
#   Text(0, 39.5, 'all'),
#   Text(0, 40.5, ' O'),
#   Text(0, 41.5, 'ack'),
#   Text(0, 42.5, ' ch'),
#   Text(0, 43.5, ' le'),
#   Text(0, 44.5, 'ies'),
#   Text(0, 45.5, 'red'),
#   Text(0, 46.5, 'ard'),
#   Text(0, 47.5, '�'),
#   Text(0, 48.5, 'out'),
#   Text(0, 49.5, ' J'),
#   Text(0, 50.5, ' ab'),
#   Text(0, 51.5, 'ear'),
#   Text(0, 52.5, 'iv'),
#   Text(0, 53.5, 'ally'),
#   Text(0, 54.5, 'our'),
#   Text(0, 55.5, 'ost'),
#   Text(0, 56.5, 'gh'),
#   Text(0, 57.5, 'pt'),
#   Text(0, 58.5, ' pl'),
#   Text(0, 59.5, 'ast'),
#   Text(0, 60.5, ' can'),
#   Text(0, 61.5, 'ak'),
#   Text(0, 62.5, 'ome'),
#   Text(0, 63.5, 'ud'),
#   Text(0, 64.5, 'The'),
#   Text(0, 65.5, ' his'),
#   Text(0, 66.5, ' do'),
#   Text(0, 67.5, ' go'),
#   Text(0, 68.5, ' has'),
#   Text(0, 69.5, 'ge'),
#   Text(0, 70.5, "'t"),
#   Text(0, 71.5, ' U'),
#   Text(0, 72.5, 'rou'),
#   Text(0, 73.5, ' sa'),
#   Text(0, 74.5, ' j'),
#   Text(0, 75.5, ' but'),
#   Text(0, 76.5, ' wor'),
#   Text(0, 77.5, ' all'),
#   Text(0, 78.5, 'ect'),
#   Text(0, 79.5, ' k'),
#   Text(0, 80.5, 'ame'),
#   Text(0, 81.5, ' will'),
#   Text(0, 82.5, 'ok'),
#   Text(0, 83.5, ' whe'),
#   Text(0, 84.5, ' they'),
#   Text(0, 85.5, 'ide'),
#   Text(0, 86.5, '01'),
#   Text(0, 87.5, 'ff'),
#   Text(0, 88.5, 'ich'),
#   Text(0, 89.5, 'pl'),
#   Text(0, 90.5, 'ther'),
#   Text(0, 91.5, ' tr'),
#   Text(0, 92.5, '..'),
#   Text(0, 93.5, ' int'),
#   Text(0, 94.5, 'ie'),
#   Text(0, 95.5, 'ure'),
#   Text(0, 96.5, 'age'),
#   Text(0, 97.5, ' ne'),
#   Text(0, 98.5, 'ial'),
#   Text(0, 99.5, 'ap')])

# %%
max_data = np.argmax(logits_data, axis=1)
for i, e in zip(max_data, range(vocab_size)):
    print(f"start: '{enc.decode([e])}', next: {enc.decode([i])}")
# Out:
# start: '!', next:
#
# start: '"', next: I
# start: '#', next: ,
# start: '$', next: ,
# start: '%', next: ,
# start: '&', next: ,
# start: ''', next: er
# start: '(', next: 2
# start: ')', next: ,
# start: '*', next: ,
# start: '+', next: ,
# start: ',', next:
#
# start: '-', next:
#
# start: '.', next:
#
# start: '/', next:  the
# start: '0', next: ,
# start: '1', next:
#
# start: '2', next: ,
# start: '3', next:  KING
# start: '4', next: ,
# start: '5', next: ,
# start: '6', next: ,
# start: '7', next: ,
# start: '8', next: ,
# start: '9', next: ,
# start: ':', next:
#
# start: ';', next:
#
# start: '<', next: ,
# start: '=', next: ,
# start: '>', next: ,
# start: '?', next:
#
# start: '@', next: ,
# start: 'A', next: ,
# start: 'B', next: UCK
# start: 'C', next: ES
# start: 'D', next: U
# start: 'E', next:
#
# start: 'F', next: ID
# start: 'G', next: AR
# start: 'H', next: EN
# start: 'I', next: US
# start: 'J', next: UL
# start: 'K', next: ATH
# start: 'L', next: AD
# start: 'M', next: IR
# start: 'N', next: urse
# start: 'O', next: ,
# start: 'P', next: OM
# start: 'Q', next: UE
# start: 'R', next: U
# start: 'S', next: IC
# start: 'T', next: :
# start: 'U', next: CH
# start: 'V', next: INC
# start: 'W', next: ICK
# start: 'X', next: ,
# start: 'Y', next: ORK
# start: 'Z', next: AL
# start: '[', next: Ill
# start: '\', next: ,
# start: ']', next:
#
# start: '^', next: ,
# start: '_', next: ,
# start: '`', next: ,
# start: 'a', next:
#
# start: 'b', next: alt
# start: 'c', next: annot
# start: 'd', next:
#
# start: 'e', next: ,
# start: 'f', next: ,
# start: 'g', next:
#
# start: 'h', next: undred
# start: 'i', next: ,
# start: 'j', next: umped
# start: 'k', next: ons
# start: 'l', next: ,
# start: 'm', next: ,
# start: 'n', next: oe
# start: 'o', next: ,
# start: 'p', next:
#
# start: 'q', next: ,
# start: 'r', next: ,
# start: 's', next:
#
# start: 't', next: ,
# start: 'u', next: ,
# start: 'v', next: its
# start: 'w', next: arks
# start: 'x', next: ,
# start: 'y', next:
#
# start: 'z', next: uk
# start: '{', next: ,
# start: '|', next: AR
# start: '}', next: ,
# start: '~', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next:  not
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: :
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next:
#
# start: '�', next: ay
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: EN
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: US
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next:
#
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '', next: uz
# start: '', next: ,
# start: '', next: ,
# start: '', next: ,
# start: '', next:  the
# start: '', next: ,
# start: '', next: ,
# start: '', next: ,
# start: ', next: ,
# start: '	', next: ,
# start: '
# ', next:
#
# start: '', next: ,
# start: '', next: ,
# ', next: ,
# start: '', next: ,
# start: '', next: ,
# start: '', next: ,
# start: '', next: ,
# start: '', next: ,
# start: '', next: ,
# start: '', next: ,
# start: '', next: ,
# start: '', next: ut
# start: '', next: ,
# start: '', next: ,
# start: '', next: ,
# start: '', next: ,
# start: '', next: ,
# start: '', next: ,
# start: '', next: ,
# start: '', next: ,
# start: '', next: ,
# start: ' ', next:
# start: '', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: uz
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: s
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next:
#
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: '�', next: ,
# start: ' t', next: ,
# start: ' a', next:
#
# start: 'he', next: v
# start: 'in', next: ,
# start: 're', next:
#
# start: 'on', next: ,
# start: ' the', next:
#
# start: 'er', next: ,
# start: ' s', next: ,
# start: 'at', next: ,
# start: ' w', next: oe
# start: ' o', next: '
# start: 'en', next: ,
# start: ' c', next: ,
# start: 'it', next: hee
# start: 'is', next: ,
# start: 'an', next:
#
# start: 'or', next: ,
# start: 'es', next: ,
# start: ' b', next: aw
# start: 'ed', next: ,
# start: ' f', next: ie
# start: 'ing', next: ,
# start: ' p', next: uc
# start: 'ou', next: ,
# start: ' an', next: ,
# start: 'al', next:
#
# start: 'ar', next: ovo
# start: ' to', next:  be
# start: ' m', next: irth
# start: ' of', next:  the
# start: ' in', next:  the
# start: ' d', next: oth
# start: ' h', next: uss
# start: ' and', next:
#
# start: 'ic', next: ,
# start: 'as', next: ,
# start: 'le', next:
#
# start: ' th', next: ine
# start: 'ion', next: ,
# start: 'om', next: ,
# start: 'll', next:
#
# start: 'ent', next:
#
# start: ' n', next: ,
# start: ' l', next: ,
# start: 'st', next: ,
# start: ' re', next: ,
# start: 've', next:  be
# start: ' e', next: re
# start: 'ro', next: ther
# start: 'ly', next: ,
# start: ' be', next:
#
# start: ' g', next: entry
# start: ' T', next: ush
# start: 'ct', next: ,
# start: ' S', next: perm
# start: 'id', next: ius
# start: 'ot', next: :
# start: ' I', next:  am
# start: 'ut', next: ant
# start: 'et', next: ,
# start: ' A', next: hab
# start: ' is', next:  the
# start: ' on', next:  the
# start: 'im', next: ,
# start: 'am', next: ma
# start: 'ow', next: ards
# start: 'ay', next: lov
# start: 'ad', next: ,
# start: 'se', next: emed
# start: ' that', next:  the
# start: ' C', next: oss
# start: 'ig', next: sen
# start: ' for', next:
#
# start: 'ac', next: ,
# start: ' y', next: onder
# start: 'ver', next: ,
# start: 'ur', next:
#
# start: ' u', next: hl
# start: 'ld', next: ,
# start: ' st', next: eed
# start: ' M', next: ikh
# start: ''s', next:
#
# start: ' he', next:
#
# start: ' it', next:  is
# start: 'ation', next: :
# start: 'ith', next: ,
# start: 'ir', next: ,
# start: 'ce', next:  the
# start: ' you', next:
#
# start: 'il', next: ,
# start: ' B', next: OL
# start: ' wh', next: aling
# start: 'ol', next: ens
# start: ' P', next: ety
# start: ' with', next:  a
# start: ' 1', next: ,
# start: 'ter', next: :
# start: 'ch', next: ,
# start: ' as', next:
#
# start: ' we', next:  the
# start: ' (', next: ,
# start: 'nd', next: ,
# start: 'ill', next:  the
# start: ' D', next: ron
# start: 'if', next: ,
# start: ' 2', next:  and
# start: 'ag', next: :
# start: 'ers', next: ,
# start: 'ke', next:  the
# start: ' "', next:
#
# start: ' H', next: EN
# start: 'em', next: ois
# start: ' con', next:
#
# start: ' W', next: ,
# start: ' R', next: ICH
# start: 'her', next: ,
# start: ' was', next:
#
# start: ' r', next: ouse
# start: 'od', next: ino
# start: ' F', next: :
# start: 'ul', next: ,
# start: 'ate', next: ,
# start: ' at', next:  the
# start: 'ri', next: ev
# start: 'pp', next: ,
# start: 'ore', next:
#
# start: ' The', next:
#
# start: ' se', next: rene
# start: 'us', next: ,
# start: ' pro', next: digy
# start: ' ha', next: p
# start: 'um', next: io
# start: ' are', next:
#
# start: ' de', next: ,
# start: 'ain', next: ,
# start: 'and', next: ,
# start: ' or', next:
#
# start: 'igh', next:  the
# start: 'est', next: ,
# start: 'ist', next: ,
# start: 'ab', next: ,
# start: 'rom', next: ,
# start: ' N', next: ant
# start: 'th', next: ou
# start: ' com', next:
#
# start: ' G', next: aunt
# start: 'un', next:
#
# start: 'op', next: chin
# start: '00', next: ,
# start: ' L', next: EW
# start: ' not', next:
#
# start: 'ess', next: ,
# start: ' ex', next: cell
# start: ' v', next: anguard
# start: 'res', next: ,
# start: ' E', next: LY
# start: 'ew', next: ,
# start: 'ity', next: ,
# start: 'ant', next: ,
# start: ' by', next:  the
# start: 'el', next: ,
# start: 'os', next:
#
# start: 'ort', next: ,
# start: 'oc', next: ,
# start: 'qu', next: od
# start: ' from', next:  the
# start: ' have', next:
#
# start: ' su', next: itor
# start: 'ive', next:
#
# start: 'ould', next: ,
# start: ' sh', next: ,
# start: ' this', next: ,
# start: 'nt', next: ,
# start: 'ra', next: ,
# start: 'pe', next: cul
# start: 'ight', next: ,
# start: 'art', next: illery
# start: 'ment', next: ,
# start: ' al', next: oft
# start: 'ust', next: ,
# start: 'end', next:
#
# start: '--', next:
#
# start: 'all', next: ,
# start: ' O', next: ,
# start: 'ack', next: ,
# start: ' ch', next: oler
# start: ' le', next: vi
# start: 'ies', next: ,
# start: 'red', next: ,
# start: 'ard', next: ,
# start: '�', next: �
# start: 'out', next: ,
# start: ' J', next: ove
# start: ' ab', next: ode
# start: 'ear', next: ,
# start: 'iv', next: ,
# start: 'ally', next: ,
# start: 'our', next: ,
# start: 'ost', next: ov
# start: 'gh', next: :
# start: 'pt', next: ,
# start: ' pl', next: uck
# start: 'ast', next: ,
# start: ' can', next: ,
# start: 'ak', next: ,
# start: 'ome', next: o
# start: 'ud', next:
#
# start: 'The', next:
#
# start: ' his', next:
#
# start: ' do', next:
#
# start: ' go', next: ,
# start: ' has', next:
#
# start: 'ge', next: ,
# start: ''t', next: ,
# start: ' U', next: lyss
# start: 'rou', next:
#
# start: ' sa', next: ,
# start: ' j', next:
#
# start: ' but', next:
#
# start: ' wor', next: ,
# start: ' all', next:
#
# start: 'ect', next: ,
# start: ' k', next:  the
# start: 'ame', next: ,
# start: ' will', next:
#
# start: 'ok', next: hov
# start: ' whe', next: IO
# start: ' they', next:
#
# start: 'ide', next: ,
# start: '01', next: ,
# start: 'ff', next: ,
# start: 'ich', next: ,
# start: 'pl', next: ,
# start: 'ther', next: ,
# start: ' tr', next: ifles
# start: '..', next: ,
# start: ' int', next: ently
# start: 'ie', next: ,
# start: 'ure', next: ,
# start: 'age', next:
#
# start: ' ne', next:
#
# start: 'ial', next: ,
# start: 'ap', next: arte
# start: 'ine', next: ,
# start: 'ice', next: ,
# start: ' me', next:
#
# start: ' out', next:
#
# start: 'ans', next: ,
# start: 'one', next: ers
# start: 'ong', next: ,
# start: 'ions', next: IO
# start: ' who', next:  had
# start: ' K', next: ras
# start: ' up', next:  to
# start: ' their', next: ,
# start: ' ad', next: rift
# start: ' 3', next: ,
# start: ' us', next: ,
# start: 'ated', next: ,
# start: 'ous', next:
#
# start: ' more', next:  than
# start: 'ue', next:
#
# start: 'og', next: ,
# start: ' St', next: ubb
# start: 'ind', next: eed
# start: 'ike', next: ,
# start: ' so', next: ,
# start: 'ime', next: ,
# start: 'per', next: anski
# start: '."', next:
#
# start: 'ber', next: ,
# start: 'iz', next: ,
# start: 'act', next:
#
# start: ' one', next:
#
# start: ' said', next:  the
# start: ' -', next: ,
# start: 'are', next: well
# start: ' your', next:
#
# start: 'cc', next: ,
# start: ' Th', next:  the
# start: ' cl', next:
#
# start: 'ep', next: ,
# start: 'ake', next: ,
# start: 'able', next:
#
# start: 'ip', next: ,
# start: ' cont', next: rived
# start: ' which', next:
#
# start: 'ia', next: ,
# start: ' im', next: pelled
# start: ' about', next:  the
# start: ' were', next:
#
# start: 'very', next:  and
# start: 'ub', next: ber
# start: ' had', next:  been
# start: ' en', next: vious
# start: ' comp', next: ,
# start: ',"', next:  said
# start: ' In', next: ,
# start: ' un', next: ,
# start: ' ag', next: ,
# start: 'ire', next: ,
# start: 'ace', next:
#
# start: 'au', next: ,
# start: 'ary', next: ,
# start: ' would', next:  be
# start: 'ass', next: ,
# start: 'ry', next: ,
# start: ' �', next: �
# start: 'cl', next: ,
# start: 'ook', next: ,
# start: 'ere', next:
#
# start: 'so', next: ,
# start: ' V', next: INC
# start: 'ign', next: ,
# start: 'ib', next:  the
# start: ' off', next: ,
# start: ' te', next: ,
# start: 'ven', next: ,
# start: ' Y', next: ,
# start: 'ile', next: ,
# start: 'ose', next:  and
# start: 'ite', next: ,
# start: 'orm', next: ,
# start: ' 201', next: ,
# start: ' res', next: olute
# start: ' man', next: ,
# start: ' per', next: ils
# start: ' other', next: ,
# start: 'ord', next: ,
# start: 'ult', next: ,
# start: ' been', next:
#
# start: ' like', next:
#
# start: 'ase', next: ,
# start: 'ance', next: ,
# start: 'ks', next: ,
# start: 'ays', next: ,
# start: 'own', next: ,
# start: 'ence', next: ,
# start: ' dis', next: ,
# start: 'ction', next: ,
# start: ' any', next:
#
# start: ' app', next: ,
# start: ' sp', next: ake
# start: 'int', next: ,
# start: 'ress', next: ,
# start: 'ations', next: ,
# start: 'ail', next:
#
# start: ' 4', next:  the
# start: 'ical', next: ,
# start: ' them', next:
#
# start: ' her', next:
#
# start: 'ount', next: ,
# start: ' Ch', next: ,
# start: ' ar', next: ,
# start: ' if', next:  to
# start: ' there', next:
#
# start: ' pe', next: ,
# start: ' year', next:  the
# start: 'av', next:
#
# start: ' my', next:
#
# start: ' some', next: ,
# start: ' when', next: ,
# start: 'ough', next: ,
# start: 'ach', next: ,
# start: ' than', next:
#
# start: 'ru', next: chio
# start: 'ond', next:
#
# start: 'ick', next: ,
# start: ' over', next: ,
# start: 'vel', next: ,
# start: ' qu', next: itted
# start: '
#
# ', next:
#
#
# start: ' sc', next: ,
# start: 'reat', next: ,
# start: 'ree', next: ,
# start: ' It', next:  the
# start: 'ound', next: :
# start: 'port', next: ,
# start: ' also', next: ,
# start: ' part', next:
#
# start: 'fter', next: ,
# start: ' kn', next: aves
# start: ' bec', next: ,
# start: ' time', next:  the
# start: 'ens', next: k
# start: ' 5', next: ,
# start: 'ople', next: ,
# start: ' what', next:  the
# start: ' no', next:  more
# start: 'du', next: ke
# start: 'mer', next: ,
# start: 'ang', next: ,
# start: ' new', next: ,
# start: '----', next: ,
# start: ' get', next:
#
# start: 'ory', next: ,
# start: 'ition', next: ,
# start: 'ings', next:
#
# start: ' just', next: ,
# start: ' into', next:  the
# start: ' 0', next: ,
# start: 'ents', next: ,
# start: 'ove', next: ,
# start: 'te', next: go
# start: ' people', next: ,
# start: ' pre', next: ,
# start: ' its', next: ,
# start: ' rec', next: ,
# start: ' tw', next: itched
# start: 'ian', next: ,
# start: 'irst', next: ,
# start: 'ark', next: ,
# start: 'ors', next: ,
# start: ' work', next: ,
# start: 'ade', next: ,
# start: 'ob', next:  the
# start: ' she', next:
#
# start: ' our', next:
#
# start: 'wn', next: ,
# start: 'ink', next: ,
# start: 'lic', next: ,
# start: ' 19', next: ,
# start: ' He', next: ,
# start: 'ish', next:
#
# start: 'nder', next:
#
# start: 'ause', next:
#
# start: ' him', next: .
# start: 'ons', next: ki
# start: ' [', next: ,
# start: ' ro', next: sy
# start: 'form', next: ,
# start: 'ild', next: ,
# start: 'ates', next: by
# start: 'vers', next: ,
# start: ' only', next:
#
# start: 'oll', next: ,
# start: ' spe', next: ,
# start: 'ck', next:  the
# start: 'ell', next: ,
# start: 'amp', next: ,
# start: ' acc', next: ursed
# start: ' bl', next: ushed
# start: 'ious', next: ,
# start: 'urn', next: ,
# start: 'ft', next: ,
# start: 'ood', next: ,
# start: ' how', next:
#
# start: 'hed', next: ,
# start: ' '', next: tis
# start: ' after', next: ,
# start: 'aw', next: ,
# start: ' att', next:  to
# start: 'ov', next: ,
# start: 'ne', next:  High
# start: ' play', next: ,
# start: 'erv', next: al
# start: 'ict', next: ,
# start: ' could', next:
#
# start: 'itt', next: :
# start: ' am', next: ,
# start: ' first', next: ,
# start: ' 6', next: ,
# start: ' act', next:
#
# start: ' $', next: ,
# start: 'ec', next: ,
# start: 'hing', next: ,
# start: 'ual', next:
#
# start: 'ull', next: ,
# start: ' comm', next: otion
# start: 'oy', next: ,
# start: 'old', next: ,
# start: 'ces', next: ,
# start: 'ater', next: ,
# start: ' fe', next: igned
# start: ' bet', next: imes
# start: 'we', next:
#
# start: 'iff', next: I
# start: ' two', next:
#
# start: 'ock', next: ,
# start: ' back', next: ,
# start: ').', next: ,
# start: 'ident', next: ,
# start: ' under', next: ,
# start: 'rough', next:
#
# start: 'sel', next: ,
# start: 'xt', next: ,
# start: ' may', next:
#
# start: 'round', next: ,
# start: ' po', next:
#
# start: 'ph', next: ,
# start: 'iss', next: ,
# start: ' des', next:  the
# start: ' most', next: :
# start: ' did', next:  not
# start: ' add', next: ,
# start: 'ject', next: ,
# start: ' inc', next: ,
# start: 'fore', next:
#
# start: ' pol', next: ,
# start: 'ont', next: ,
# start: ' again', next: ,
# start: 'clud', next: ,
# start: 'tern', next: ,
# start: ' know', next: ,
# start: ' need', next: ,
# start: ' cons', next: ul
# start: ' co', next: ,
# start: ' .', next: ,
# start: ' want', next:
#
# start: ' see', next: ,
# start: ' 7', next: :
# start: 'ning', next: ,
# start: 'iew', next: ,
# start: ' This', next: ,
# start: 'ced', next: ,
# start: ' even', next: ,
# start: ' ind', next: ,
# start: 'ty', next: ,
# start: ' We', next: ,
# start: 'ath', next: ,
# start: ' these', next:
#
# start: ' pr', next: ,
# start: ' use', next: ,
# start: ' because', next: ,
# start: ' fl', next: atter
# start: 'ng', next: ,
# start: ' now', next:
#
# start: ' –', next: ,
# start: 'com', next: ,
# start: 'ise', next: ,
# start: ' make', next: ,
# start: ' then', next: ,
# start: 'ower', next: ,
# start: ' every', next: ,
# start: ' Un', next: ,
# start: ' sec', next: ,
# start: 'oss', next: ack
# start: 'uch', next: ,
# start: ' em', next: ,
# start: ' =', next: ,
# start: ' Re', next: ,
# start: 'ied', next: ,
# start: 'rit', next: hee
# start: ' inv', next: ,
# start: 'lect', next: ,
# start: ' supp', next: osition
# start: 'ating', next: ,
# start: ' look', next:
#
# start: 'man', next: ,
# start: 'pect', next: ,
# start: ' 8', next: ,
# start: 'row', next: :
# start: ' bu', next: ,
# start: ' where', next: ,
# start: 'ific', next: ,
# start: ' years', next: ,
# start: 'ily', next: ,
# start: ' diff', next: ,
# start: ' should', next: ,
# start: ' rem', next:
#
# start: 'Th', next: ou
# start: 'In', next: ,
# start: ' ev', next: ,
# start: 'day', next: ,
# start: ''re', next: ,
# start: 'rib', next: ,
# start: ' rel', next:
#
# start: 'ss', next:
#
# start: ' def', next: ,
# start: ' right', next: ,
# start: ' sy', next: ,
# start: '),', next:
#
# start: 'les', next: ,
# start: '000', next:  lbs
# start: 'hen', next:
#
# start: ' through', next: ,
# start: ' Tr', next: ,
# start: '__', next: ,
# start: ' way', next: ,
# start: ' don', next: 't
# start: ' ,', next: ,
# start: ' 10', next: ,
# start: 'ased', next: ,
# start: ' ass', next: ,
# start: 'ublic', next: ,
# start: ' reg', next: imental
# start: ' And', next: ,
# start: 'ix', next:
#
# start: ' very', next:  to
# start: ' includ', next: ,
# start: 'other', next: ,
# start: ' imp', next: ,
# start: 'oth', next:
#
# start: ' sub', next: missive
# start: ' —', next: _
# start: ' being', next: ,
# start: 'arg', next: ,
# start: ' Wh', next:
#
# start: '==', next: ,
# start: 'ible', next:
#
# start: ' does', next: ,
# start: 'ange', next: ,
# start: 'ram', next: ,
# start: ' 9', next:
#
# start: 'ert', next: ,
# start: 'ps', next: ,
# start: 'ited', next:  be
# start: 'ational', next: ,
# start: ' br', next: ,
# start: ' down', next: ,
# start: ' many', next: ,
# start: 'aking', next: ,
# start: ' call', next: ,
# start: 'uring', next: ,
# start: 'ities', next: ,
# start: ' ph', next: ,
# start: 'ics', next: ,
# start: 'als', next: ,
# start: ' dec', next:  the
# start: 'ative', next: ,
# start: 'ener', next: ,
# start: ' before', next:
#
# start: 'ility', next: ,
# start: ' well', next: ,
# start: ' much', next:
#
# start: 'erson', next: ,
# start: ' those', next: ,
# start: ' such', next: ,
# start: ' ke', next: ,
# start: ' end', next: ,
# start: ' But', next: ,
# start: 'ason', next: ,
# start: 'ting', next: ,
# start: ' long', next: ,
# start: 'ef', next:  the
# start: ' think', next:  the
# start: 'ys', next:  to
# start: ' bel', next: ike
# start: ' sm', next: ith
# start: 'its', next: ki
# start: 'ax', next: ,
# start: ' own', next:
#
# start: ' prov', next: ,
# start: ' set', next: ,
# start: 'ife', next: ,
# start: 'ments', next: ,
# start: 'ble', next: ,
# start: 'ward', next: ,
# start: ' show', next: :
# start: ' pres', next: ,
# start: 'ms', next: ,
# start: 'omet', next: ,
# start: ' ob', next: sequ
# start: ' say', next: :
# start: ' Sh', next: ,
# start: 'ts', next: hire
# start: 'ful', next: ,
# start: ' eff', next: ,
# start: ' gu', next: ,
# start: ' inst', next: ,
# start: 'und', next: ,
# start: 'ren', next:
#
# start: 'cess', next:  Mary
# start: ' ent', next: reat
# start: ' You', next: ,
# start: ' good', next: ,
# start: ' start', next: ,
# start: 'ince', next: ,
# start: ' made', next: ,
# start: 'tt', next: ,
# start: 'stem', next: ,
# start: 'olog', next: ,
# start: 'up', next:
#
# start: ' |', next: ,
# start: 'ump', next: ,
# start: ' hel', next: ,
# start: 'vern', next: ,
# start: 'ular', next: ,
# start: 'ually', next: ,
# start: ' ac', next: ,
# start: ' mon', next:  cher
# start: ' last', next: ,
# start: ' 200', next: ,
# start: '10', next: ,
# start: ' stud', next:  the
# start: 'ures', next: ,
# start: ' Ar', next: ,
# start: 'self', next:
#
# start: 'ars', next: ,
# start: 'meric', next: ,
# start: 'ues', next:
#
# start: 'cy', next: ,
# start: ' min', next: ,
# start: 'ollow', next: ,
# start: ' col', next: ,
# start: 'io', next: ,
# start: ' mod', next: ,
# start: ' count', next: ess
# start: ' Com', next: ,
# start: 'hes', next: ,
# start: ' fin', next: ,
# start: 'air', next: ,
# start: 'ier', next: ,
# start: '—', next:  the
# start: 'read', next: ,
# start: 'ank', next:
#
# start: 'atch', next: ,
# start: 'ever', next: ,
# start: ' str', next: aining
# start: ' point', next: ,
# start: 'ork', next:
#
# start: ' New', next:  Bedford
# start: ' sur', next: ,
# start: 'ool', next:  of
# start: 'alk', next: ,
# start: 'ement', next: ,
# start: ' used', next: ,
# start: 'ract', next: ,
# start: 'ween', next: ,
# start: ' same', next: ,
# start: 'oun', next: ,
# start: ' Al', next: pat
# start: 'ci', next: ,
# start: ' differe', next: ,
# start: ' while', next: ,
# start: '--------', next: ,
# start: ' game', next: ,
# start: 'cept', next:  of
# start: ' sim', next: ,
# start: '...', next:  the
# start: ' inter', next: ,
# start: 'ek', next: ,
# start: ' report', next: ,
# start: ' produ', next: ,
# start: ' still', next: ,
# start: 'led', next: ,
# start: 'ah', next: awk
# start: ' here', next: ,
# start: ' world', next: ,
# start: ' though', next: ,
# start: ' num', next: ,
# start: 'arch', next: ,
# start: 'imes', next: ,
# start: 'ale', next: ,
# start: ' Se', next: ,
# start: ' If', next: ,
# start: '//', next: ,
# start: ' Le', next: ,
# start: ' ret', next: ,
# start: ' ref', next: ,
# start: ' trans', next: ference
# start: 'ner', next: ,
# start: 'ution', next: ,
# start: 'ters', next: ,
# start: ' take', next: ,
# start: ' Cl', next: audio
# start: ' conf', next: lag
# start: 'way', next: ,
# start: 'ave', next: ,
# start: ' going', next:
#
# start: ' sl', next: ,
# start: 'ug', next: nance
# start: ' Americ', next: ,
# start: ' spec', next: ,
# start: ' hand', next:  and
# start: ' between', next: ,
# start: 'ists', next: ,
# start: ' De', next: ,
# start: 'oot', next: ,
# start: 'It', next: ,
# start: ' ear', next: ,
# start: ' against', next: ,
# start: ' high', next: ,
# start: 'gan', next: ,
# start: 'az', next: ,
# start: 'ather', next: ,
# start: ' exp', next: ,
# start: ' op', next: ,
# start: ' ins', next: ,
# start: ' gr', next: ,
# start: ' help', next: ,
# start: ' requ', next: ,
# start: 'ets', next: ,
# start: 'ins', next: hin
# start: ' Pro', next:
#
# start: 'ism', next:
#
# start: ' found', next: ,
# start: 'land', next:
#
# start: 'ata', next: ev
# start: 'uss', next: ars
# start: 'ames', next: ,
# start: ' person', next: ,
# start: ' great', next:
#
# start: 'pr', next: ince
# start: ' sign', next:
#
# start: ' An', next: ,
# start: ''ve', next: ,
# start: ' somet', next: ,
# start: ' ser', next: fs
# start: 'hip', next: ,
# start: ' run', next: ,
# start: ' :', next: ,
# start: ' ter', next: rors
# start: 'irect', next: ,
# start: ' follow', next: ,
# start: ' det', next: ,
# start: 'ices', next: ,
# start: ' find', next: ,
# start: '12', next: ,
# start: ' mem', next: ,
# start: ' cr', next: ,
# start: 'ered', next: ,
# start: 'ex', next: pect
# start: ' ext', next: ,
# start: 'uth', next: ,
# start: 'ense', next: ,
# start: 'co', next: ats
# start: ' team', next: ,
# start: 'ving', next:
#
# start: 'ouse', next: EN
# start: 'ash', next: te
# start: 'att', next: ention
# start: 'ved', next: ,
# start: ' system', next: ,
# start: ' As', next: ,
# start: 'der', next: ,
# start: 'ives', next: ,
# start: 'min', next: ,
# start: ' lead', next: :
# start: ' Bl', next: unt
# start: 'cent', next: io
# start: ' around', next: ,
# start: ' govern', next: ,
# start: ' cur', next: ,
# start: 'velop', next: ,
# start: 'any', next: ,
# start: ' cour', next: ,
# start: 'alth', next: ,
# start: 'ages', next:
#
# start: 'ize', next: ,
# start: ' car', next: penter
# start: 'ode', next: ,
# start: ' law', next: ,
# start: ' read', next: ,
# start: ''m', next: ,
# start: 'con', next: vers
# start: ' real', next: ,
# start: ' support', next: ,
# start: ' 12', next: ,
# start: '....', next: ,
# start: ' really', next: ,
# start: 'ness', next: ,
# start: ' fact', next: ,
# start: ' day', next: ,
# start: ' both', next:  sides
# start: 'ying', next: ,
# start: ' serv', next: ,
# start: ' For', next: ,
# start: ' three', next: ,
# start: ' wom', next: ,
# start: ' med', next: ,
# start: 'ody', next: ,
# start: ' They', next: :
# start: '50', next: ,
# start: ' exper', next:
#
# start: 'ton', next: ,
# start: ' each', next: ,
# start: 'akes', next: ,
# start: ' che', next: ,
# start: ' cre', next: aked
# start: 'ines', next: ,
# start: ' rep', next: roach
# start: '19', next: ,
# start: 'gg', next:
#
# start: 'illion', next: ,
# start: ' grou', next: ,
# start: 'ute', next: ,
# start: 'ik', next: ,
# start: 'We', next: ,
# start: 'get', next: ,
# start: 'ER', next: LE
# start: ' met', next: ,
# start: ' says', next: ,
# start: 'ox', next: ,
# start: ' during', next: ,
# start: 'ern', next: ,
# start: 'ized', next: ,
# start: 'ared', next: :
# start: ' fam', next:
#
# start: 'ically', next: ,
# start: ' happ', next: ,
# start: ' Is', next: ,
# start: ' char', next: nel
# start: 'med', next: ,
# start: 'vent', next:  the
# start: ' gener', next:
#
# start: 'ient', next: ,
# start: 'ple', next: asure
# start: 'iet', next: ,
# start: 'rent', next: ,
# start: '11', next: ,
# start: 'ves', next: ,
# start: 'ption', next: ,
# start: ' 20', next: ,
# start: 'formation', next: ,
# start: ' cor', next: ,
# start: ' offic', next:
#
# start: 'ield', next: ,
# start: ' too', next: ,
# start: 'ision', next:  said
# start: ' inf', next: ov
# start: ' Z', next: ,
# start: 'the', next: ,
# start: 'oad', next: ,
# start: ' public', next: ,
# start: ' prog', next: eny
# start: 'ric', next: ians
# start: '**', next: ,
# start: ' war', next: ,
# start: ' power', next: ,
# start: 'view', next: ,
# start: ' few', next: ,
# start: ' loc', next: ,
# start: ' different', next: ,
# start: ' state', next: ,
# start: ' head', next:  the
# start: ''ll', next: ,
# start: ' poss', next:
#
# start: ' stat', next: ,
# start: 'ret', next: ,
# start: 'ants', next: ,
# start: ' val', next: et
# start: ' iss', next: ,
# start: ' cle', next:
#
# start: 'ivers', next:  a
# start: 'anc', next: ,
# start: ' expl', next: ,
# start: ' another', next: ,
# start: ' Q', next: ,
# start: ' av', next: ,
# start: 'thing', next: ,
# start: 'nce', next:  of
# start: 'Wh', next: ose
# start: ' child', next: ,
# start: ' since', next: ,
# start: 'ired', next: ,
# start: 'less', next:  the
# start: ' life', next: ,
# start: ' develop', next: ,
# start: 'ittle', next: ,
# start: ' dep', next: osed
# start: ' pass', next: ,
# start: '�', next: ,
# start: ' turn', next: ,
# start: 'orn', next: ,
# start: 'This', next:  is
# start: 'bers', next:
#
# start: 'ross', next: ,
# start: ' Ad', next: ,
# start: ' fr', next: inged
# start: ' resp', next:
#
# start: ' second', next:  and
# start: 'oh', next: ,
# start: ' /', next: ,
# start: ' disc', next: ,
# start: ' &', next:
#
# start: ' something', next: ,
# start: ' comple', next: teness
# start: ' ed', next:  to
# start: ' fil', next: ,
# start: ' month', next: ,
# start: 'aj', next: ,
# start: 'uc', next: kered
# start: ' government', next:
#
# start: ' without', next: ,
# start: ' leg', next: ,
# start: ' dist', next: EN
# start: ' put', next: :
# start: ' quest', next: ,
# start: 'ann', next: ,
# start: ' prot', next: ,
# start: '20', next: ,
# start: ' never', next: ,
# start: 'ience', next: ,
# start: ' level', next:
#
# start: ' art', next: ,
# start: ' things', next: ,
# start: ' might', next: ,
# start: ' effect', next: ,
# start: ' contro', next: EN
# start: ' cent', next: ,
# start: ' 18', next: 07
# start: ' allow', next: ,
# start: ' belie', next: ,
# start: 'chool', next: ,
# start: 'ott', next: agers
# start: ' incre', next: ,
# start: ' feel', next: ,
# start: ' result', next: ,
# start: ' lot', next: ,
# start: ' fun', next: ,
# start: 'ote', next: ,
# start: ' ty', next: ,
# start: 'erest', next:
#
# start: ' contin', next: ,
# start: ' using', next: ,
# start: ' big', next: ,
# start: '201', next: ,
# start: ' ask', next: ,
# start: ' best', next:
#
# start: ' )', next: ,
# start: 'IN', next: I
# start: ' opp', next: ,
# start: '30', next: ,
# start: ' number', next:
#
# start: 'iness', next: ,
# start: 'St', next: ,
# start: 'lease', next: ,
# start: ' ca', next: ,
# start: ' must', next:
#
# start: ' direct', next: ,
# start: ' gl', next: ancing
# start: ' <', next: ,
# start: ' open', next:
#
# start: ' post', next: ,
# start: ' come', next:
#
# start: ' seem', next: ,
# start: 'ording', next: ,
# start: ' week', next: ,
# start: 'ately', next:
#
# start: 'ital', next: ,
# start: ' el', next: ,
# start: 'riend', next: ,
# start: ' far', next: ,
# start: ' tra', next: itors
# start: 'inal', next: ,
# start: ' pri', next: ,
# start: ' US', next: ,
# start: ' place', next: ,
# start: ' form', next: ,
# start: ' told', next:
#
# start: '":', next: ,
# start: 'ains', next: ,
# start: 'ature', next: ,
# start: ' Trump', next: ,
# start: ' stand', next: :
# start: ' #', next: ,
# start: 'ider', next: ,
# start: ' Fr', next: :
# start: ' next', next: ,
# start: ' soc', next: ,
# start: ' pur', next: ,
# start: ' let', next:  the
# start: ' little', next:  the
# start: ' hum', next: bly
# start: ' i', next: '
# start: 'ron', next: ,
# start: '15', next: ,
# start: ' 15', next: ,
# start: ' commun', next:
#
# start: ' mark', next: ,
# start: ' There', next: ,
# start: ' wr', next: angling
# start: ' That', next:
#
# start: ' information', next: ,
# start: 'ways', next: ,
# start: ' bus', next: ,
# start: 'app', next: eared
# start: ' invest', next: ,
# start: 'me', next: ,
# start: ' hard', next: ,
# start: 'ained', next:  the
# start: 'ead', next: ,
# start: ' import', next:  the
# start: ' appro', next:  the
# start: ' test', next: ,
# start: ' tri', next: ,
# start: ' rest', next:
#
# start: 'osed', next: ,
# start: ' full', next: ,
# start: ' care', next: ,
# start: ' Sp', next: ,
# start: ' case', next: ,
# start: 'ON', next: Z
# start: ' sk', next: ,
# start: ' less', next: ,
# start: ' +', next: ,
# start: ' partic', next: ,
# start: ' Pl', next: aton
# start: 'ably', next: :
# start: 'uck', next: ,
# start: 'ished', next: ,
# start: 'chn', next: ,
# start: 'be', next: gan
# start: ' list', next: ,
# start: 'ator', next: ,
# start: ' top', next: ,
# start: ' adv', next: ,
# start: ' Be', next: z
# start: 'ruct', next: ,
# start: ' dem', next: ,
# start: 'ration', next: ,
# start: 'ling', next:
#
# start: 'gy', next: :
# start: 'reen', next: ,
# start: 'ger', next: ,
# start: ' home', next: ,
# start: ' left', next:  the
# start: ' better', next: ,
# start: ' data', next: ,
# start: ' 11', next: ,
# start: ' attack', next: ,
# start: ' proble', next: ,
# start: 'line', next: ,
# start: 'ards', next: ,
# start: ' beh', next: ,
# start: 'ral', next: ,
# start: ' How', next: ,
# start: ' She', next:
#
# start: 'arge', next: ,
# start: ' --', next: ,
# start: '://', next: ,
# start: ' bro', next: ok
# start: ' Ph', next: :
# start: 'ats', next:
#
# start: ' build', next: ,
# start: 'ww', next: ,
# start: 'ided', next:
#
# start: 'aim', next: ,
# start: 'ases', next:  of
# start: 'ency', next: ,
# start: ' main', next: ,
# start: 'ined', next:  and
# start: ' including', next: ,
# start: ' {', next: ,
# start: ' got', next: ,
# start: ' interest', next: ,
# start: ' keep', next: ,
# start: ' X', next: ,
# start: ' eas', next: ,
# start: 'aining', next:
#
# start: ' class', next: ,
# start: '…', next: ,
# start: ' No', next: ,
# start: ' var', next: ,
# start: ' small', next: ,
# start: 'ample', next: ,
# start: 'AT', next: ,
# start: ' ide', next: ,
# start: ' So', next: ,
# start: ' rece', next: ,
# start: ' polit', next: ,
# start: ' mov', next: ,
# start: ' plan', next: ks
# start: ' percent', next: ,
# start: 'iving', next: ,
# start: ' camp', next: fires
# start: ' pay', next: ,
# start: '14', next: ,
# start: 'sc', next: ream
# start: 'ised', next: ,
# start: ' unt', next: ,
# start: 'oney', next: ,
# start: 'ploy', next: ,
# start: '====', next: ,
# start: ' didn', next: ,
# start: ' Ind', next: ,
# start: 'els', next: ,
# start: 'ertain', next: ,
# start: ' pos', next: ,
# start: '____', next:  and
# start: 'iver', next: ,
# start: ' process', next: ,
# start: ' program', next: ,
# start: 'ified', next: ,
# start: ' Rep', next: ,
# start: '16', next: ,
# start: 'uro', next: ,
# start: 'ology', next: ,
# start: 'atter', next: ,
# start: 'ina', next: ,
# start: ' name', next: ,
# start: ' All', next: ,
# start: ' four', next: ,
# start: ' return', next: ,
# start: 'vious', next:
#
# start: 'bs', next: ,
# start: ' called', next: ,
# start: ' move', next:
#
# start: ' Sc', next: ,
# start: 'ird', next: ,
# start: ' group', next: ,
# start: ' bre', next:  have
# start: ' men', next: ,
# start: ' cap', next: ,
# start: 'ten', next: ,
# start: 'ee', next: ch
# start: ' dri', next: ,
# start: 'leg', next: ,
# start: 'here', next: ,
# start: 'uthor', next: ,
# start: ' pat', next: ric
# start: ' current', next: ,
# start: 'ides', next: ,
# start: ' pop', next: ,
# start: 'to', next:
#
# start: 'ention', next: ,
# start: ' always', next:  the
# start: ' mil', next: ,
# start: ' women', next: ,
# start: ' 16', next: ,
# start: ' old', next:  man
# start: 'iven', next: ,
# start: 'raph', next: ,
# start: ' Or', next: ,
# start: 'ror', next: ,
# start: 'ently', next:
#
# start: ' near', next: ,
# start: ' Ex', next: eter
# start: 'ream', next: ,
# start: 'sh', next: ,
# start: ' 14', next: ,
# start: ' free', next: ,
# start: 'ission', next: ,
# start: 'stand', next: ,
# start: ' Con', next: ,
# start: 'ality', next: ,
# start: 'used', next: ,
# start: '13', next: ,
# start: ' design', next: ,
# start: ' change', next:  the
# start: ' chang', next: IO
# start: ' bo', next: ister
# start: ' vis', next:  the
# start: 'ember', next: ,
# start: ' book', next: ,
# start: 'ready', next: ,
# start: ' kill', next: ,
# start: '25', next: ,
# start: 'pped', next: ,
# start: ' away', next:
#
# start: ' able', next: ,
# start: ' country', next: ,
# start: ' const', next: ,
# start: 'arn', next: ,
# start: ' order', next: ,
# start: 'AR', next: ENCE
# start: 'ior', next:  Bapt
# start: 'ium', next: ,
# start: 'orth', next: ,
# start: '18', next: ,
# start: 'ailable', next: ,
# start: ' sw', next:
#
# start: ' million', next: ,
# start: ' 13', next: ,
# start: 'atic', next: ,
# start: 'ted', next: ,
# start: ' Go', next: ,
# start: ' oper', next: ,
# start: 'eng', next:  not
# start: ' thing', next: ,
# start: 'ajor', next:
#
# start: 'conom', next: ,
# start: ' Comm', next: ,
# start: ' why', next: ,
# start: 'ured', next: ,
# start: 'ural', next: ,
# start: ' school', next: ,
# start: 'by', next:
#
# start: ' Mar', next: cius
# start: ' aff', next: ords
# start: ' days', next: ,
# start: ' ann', next: ,
# start: 'ush', next: ,
# start: 'ane', next: ,
# start: 'If', next: ,
# start: 'eg', next: ,
# start: ' prof', next: ane
# start: ' health', next: ,
# start: 'outh', next: ,
# start: 'But', next:
#
# start: 'ional', next: ,
# start: '.,', next: ,
# start: ' sol', next: ,
# start: ' already', next: ,
# start: ' 30', next: ,
# start: ' charact', next: ,
# start: 'He', next: ,
# start: ' friend', next: ,
# start: 'ES', next: TER
# start: 'ians', next: ,
# start: 'icle', next: ,
# start: ''d', next: ,
# start: ' On', next: ,
# start: ' least', next: ,
# start: ' prom', next: ,
# start: ' dr', next: ago
# start: ' hist', next: ,
# start: 'ither', next: ,
# start: ' est', next: ,
# start: 'iqu', next: ,
# start: '17', next: ,
# start: 'son', next: ,
# start: ' tell', next: ,
# start: ' talk', next: ,
# start: 'ohn', next: ,
# start: 'oint', next: ,
# start: 'lection', next:  the
# start: 'AN', next: US
# start: ' until', next:  the
# start: 'augh', next:  the
# start: ' later', next: ,
# start: ' ve', next: ,
# start: ' view', next:
#
# start: 'ending', next: ,
# start: 'ived', next:
#
# start: ' word', next: ,
# start: 'ware', next: ,
# start: ' cost', next: :
# start: ' enough', next:
#
# start: ' give', next: ,
# start: ' United', next:  States
# start: ' techn', next: ,
# start: 'arent', next: ,
# start: 'OR', next: IZ
# start: ' par', next: ,
# start: ' Dr', next: issa
# start: ' 2016', next: ,
# start: 'rist', next: ,
# start: 'ering', next:  the
# start: ' �', next: ,
# start: ' large', next: ,
# start: 'side', next: ,
# start: 'acy', next: ,
# start: 'ccess', next: ,
# start: ' win', next: ,
# start: ' important', next: ,
# start: ' 199', next: ,
# start: ' doesn', next: ,
# start: ' 17', next:
#
# start: ' business', next: ,
# start: ' clear', next: ,
# start: ' rese', next: ,
# start: '",', next: ,
# start: 'ury', next: ,
# start: ' equ', next: ,
# start: 'aster', next: ,
# start: 'alf', next: ,
# start: ' American', next: ,
# start: 'nect', next: ,
# start: ' expect', next: ,
# start: 'iversity', next: ,
# start: ' occ', next: ,
# start: ' Fl', next: ,
# start: ' kind', next: ,
# start: ' mean', next: ,
# start: ' past', next: ,
# start: ' dev', next: ,
# start: ' bas', next: ,
# start: 'let', next: ,
# start: 'raft', next: ,
# start: ' organ', next: ,
# start: ' del', next: ights
# start: ' perform', next: ,
# start: ' story', next: ,
# start: ' season', next: ,
# start: ' Col', next: ,
# start: ' claim', next: ,
# start: ' came', next: ,
# start: ' within', next: ,
# start: ' line', next: ,
# start: ' project', next: ,
# start: ' At', next: ,
# start: ' control', next: ,
# start: 'ended', next: ,
# start: ' Sy', next: ,
# start: ' air', next: ,
# start: 'ization', next: ,
# start: ' *', next:  the
# start: 'ley', next: ,
# start: ' money', next: ,
# start: 'idd', next: ,
# start: 'You', next:
#
# start: 'for', next: ,
# start: ' family', next: ,
# start: ' making', next:  the
# start: ' bit', next: ,
# start: ' police', next: ,
# start: ' happen', next: ,
# start: ' vers', next: ,
# start: 'ony', next: ,
# start: 'uff', next: box
# start: ' When', next: ,
# start: ' sit', next: ,
# start: 'ideo', next: ,
# start: 'lf', next: ,
# start: 'ison', next: ,
# start: ' sure', next: ,
# start: 'gin', next: ,
# start: ' appear', next: ,
# start: ' light', next: ,
# start: ' es', next: aul
# start: 'of', next: ,
# start: ' water', next:
#
# start: ' times', next: ,
# start: 'not', next: ,
# start: ' grow', next:
#
# start: ' company', next: ,
# start: ' Te', next: ,
# start: 'ows', next: ,
# start: ' mar', next: iners
# start: 'ource', next: ,
# start: 'iol', next: anus
# start: 'arm', next: ,
# start: 'br', next: ,
# start: ' example', next: ,
# start: ' conc', next: ,
# start: ' fore', next: :
# start: ' To', next: ,
# start: 'pro', next: ,
# start: 'EN', next: RY
# start: 'ries', next: ,
# start: ' 25', next: ,
# start: ' Can', next:
#
# start: 'ney', next: ,
# start: ' actually', next: ,
# start: ' ever', next: ,
# start: 'urity', next: ,
# start: 'aken', next:
#
# start: 'aps', next: ,
# start: ' tax', next:
#
# start: ' major', next: :
# start: 'ama', next: ,
# start: ' often', next: ,
# start: 'eral', next: ET
# start: ' human', next: ,
# start: ' job', next: ,
# start: 'ister', next: ,
# start: ' available', next: ,
# start: 'ocr', next: ,
# start: 'enn', next: ,
# start: 'aid', next: ,
# start: 'ivid', next: ,
# start: ' record', next: ,
# start: '?"', next: :
# start: ' sing', next: ,
# start: ' Am', next: ,
# start: 'idence', next: ,
# start: ' news', next: ,
# start: 'ster', next: ,
# start: ' econom', next: ,
# start: ' following', next: :
# start: ' Br', next: ,
# start: 'ising', next: ,
# start: ' hour', next: ,
# start: 'most', next: ,
# start: 'ument', next: ,
# start: ' sex', next: ,
# start: ' desc', next: ried
# start: ' become', next: ,
# start: ' Ed', next: ,
# start: ' took', next:
#
# start: ' having', next:  the
# start: ' product', next: ,
# start: 'ault', next: ,
# start: 'As', next:  I
# start: 'aring', next: EN
# start: ' means', next: ,
# start: ' hop', next: ,
# start: 'une', next: ,
# start: ' cho', next: ,
# start: ' certain', next:  to
# start: ' non', next: ,
# start: ' deal', next: ,
# start: '24', next: ,
# start: 'lement', next: ,
# start: 'oci', next: ,
# start: 'ene', next: ,
# start: ' side', next: ,
# start: ' Pr', next: ussia
# start: ' May', next: ,
# start: ' reason', next:  the
# start: 'ued', next: ,
# start: 'ched', next: ,
# start: 'ulation', next: ,
# start: ' elect', next: ,
# start: ' official', next: ,
# start: ' possible', next: .
# start: ' hold', next: ,
# start: 'ands', next: ire
# start: 'ots', next: ,
# start: ' city', next: ,
# start: 'ories', next: ,
# start: ' sever', next: ,
# start: ' children', next: ,
# start: ' once', next: ,
# start: ' activ', next: ,
# start: 'ler', next: ,
# start: ' night', next: ,
# start: 'itions', next: ,
# start: ' John', next: ,
# start: 'ape', next: ,
# start: 'play', next: ,
# start: ' done', next: ,
# start: ' lim', next: ,
# start: ' working', next: ,
# start: ' Pres', next: ,
# start: 'orld', next: ,
# start: 'eb', next: ,
# start: ' Co', next:  of
# start: ' body', next: ,
# start: 'ails', next: ,
# start: 'utes', next: ,
# start: ' Mr', next: ,
# start: ' whether', next: ,
# start: ' author', next: ,
# start: 'rop', next: ,
# start: ' proper', next: ,
# start: ' seen', next: ,
# start: ');', next:
#
# start: ' fac', next: ,
# start: ' Su', next: vor
# start: ' cond', next: ,
# start: 'iting', next: ,
# start: ' course', next: ,
# start: ' }', next: ,
# start: '----------------', next: ,
# start: 'aign', next: ,
# start: ' event', next:
#
# start: ' eng', next: :
# start: ' pot', next: ,
# start: ' intern', next: ,
# start: 'iam', next: ,
# start: ' short', next: ,
# start: 'empt', next: ,
# start: '�', next:
#
# start: ' God', next: ,
# start: 'ilar', next: ,
# start: '80', next: ,
# start: ' orig', next: ,
# start: 'IS', next: AB
# start: 'ourn', next: ,
# start: 'ability', next: ,
# start: 'itive', next: ,
# start: ' dam', next: ,
# start: ' 100', next: ay
# start: ' press', next: ,
# start: ' doing', next:
#
# start: ' protect', next: ,
# start: 'ring', next:
#
# start: ' thought', next:
#
# start: ' question', next:
#
# start: 'rew', next: ,
# start: ' War', next: ,
# start: ' several', next:  times
# start: ' State', next: ,
# start: ' given', next:  to
# start: ' fund', next: ,
# start: ' Tw', next: ,
# start: ' went', next:  the
# start: 'ances', next: ,
# start: 'work', next: ,
# start: 'por', next: ,
# start: 'my', next: ,
# start: '40', next: ,
# start: ' arg', next: ,
# start: 'artment', next: ,
# start: 'ustom', next: ,
# start: ' polic', next: ,
# start: ' meet', next: ,
# start: ' creat', next: ,
# start: '22', next:
#
# start: ' States', next: ,
# start: ' games', next: ,
# start: 'raw', next: :
# start: 'uture', next: ,
# start: ' understand', next: ,
# start: 'urs', next: ,
# start: ' Ob', next: ,
# start: 'lish', next: ,
# start: 'sy', next: ,
# start: ' makes', next: ,
# start: ' won', next: 't
# start: 'agon', next: ,
# start: ' htt', next: ,
# start: ' love', next: ,
# start: 'ential', next: ,
# start: ' complete', next: ,
# start: 'par', next: allel
# start: ' Im', next: ,
# start: 'AL', next: US
# start: ' account', next:
#
# start: ' ', next: ,
# start: 'ored', next: ,
# start: 'vert', next: ,
# start: ' ident', next: ,
# start: ' 2015', next: ,
# start: ' others', next: ,
# start: ' Min', next: ola
# start: 'iber', next: ,
# start: 'verage', next: ,
# start: 'There', next: ,
# start: 'itional', next: ,
# start: 'dd', next: ,
# start: ' prob', next:
#
# start: ' young', next: ,
# start: ' along', next:
#
# start: ' according', next: ,
# start: ' yet', next:  the
# start: ' members', next: ,
# start: ' What', next: ,
# start: 'oid', next: ,
# start: ' Man', next: ,
# start: 'And', next:
#
# start: ' among', next:  the
# start: 'ai', next: ,
# start: ' employ', next:
#
# start: ' Res', next: ,
# start: ' >', next: ,
# start: ' invol', next: untarily
# start: ' low', next: ,
# start: 'af', next: ov
# start: ' Car', next: ,
# start: ' hig', next: ,
# start: ' One', next: ,
# start: ' Sec', next: ,
# start: 'ination', next: ,
# start: ' likely', next: ,
# start: ' ant', next: ,
# start: 'aged', next: ,
# start: ' Russ', next: ,
# start: ' ben', next: ,
# start: ' rele', next: ,
# start: 'For', next:
#
# start: 'back', next: ,
# start: ' Not', next: ,
# start: ' president', next: ,
# start: 'ball', next: ,
# start: ' access', next: ,
# start: 'ividual', next: ,
# start: ' Dem', next: ,
# start: ' Euro', next: ,
# start: '60', next: ,
# start: ' known', next: ,
# start: 'irl', next: ,
# start: ' Gr', next: um
# start: ' early', next:
#
# start: 'use', next: ,
# start: 'iety', next: ,
# start: '–', next: ,
# start: ' fight', next: ,
# start: ' sent', next: ,
# start: ' today', next: ,
# start: ' market', next: ,
# start: '".', next: ,
# start: ' based', next: ,
# start: ' strong', next: ,
# start: 'urther', next:
#
# start: ' deb', next: ase
# start: 'mber', next: ,
# start: ' problem', next: ,
# start: ' death', next: ,
# start: ' social', next:
#
# start: 'imate', next: ,
# start: 'AS', next: ,
# start: 'ortun', next:
#
# start: ' campaign', next: ,
# start: 'ery', next: ,
# start: 'Ch', next: ,
# start: ' ey', next: ,
# start: 'ially', next: ,
# start: ' mus', next: ket
# start: 'wh', next: ale
# start: 'pos', next: itions
# start: ' er', next: ,
# start: ' saf', next: ,
# start: ' months', next: ,
# start: 'iron', next: ,
# start: ' viol', next: ay
# start: ' five', next: ,
# start: ' stre', next: ,
# start: ' players', next: ,
# start: 'inc', next: ,
# start: 'ald', next: ,
# start: 'year', next: ,
# start: 'aun', next: ,
# start: ' success', next: ,
# start: ' present', next:
#
# start: 'erence', next: ,
# start: ' 2014', next: ,
# start: ' sugg', next: ,
# start: ' particular', next: ,
# start: ' try', next: ,
# start: ' suggest', next: ,
# start: ' Christ', next: ,
# start: 'ones', next: ,
# start: ' priv', next: ,
# start: '23', next: ,
# start: ' crit', next: ,
# start: ' land', next: ,
# start: ' local', next: ,
# start: 'ify', next: ,
# start: '29', next: ,
# start: ' aut', next: ,
# start: 'ED', next: IO
# start: ' Gu', next: ern
# start: ' mult', next: ,
# start: ' political', next: ,
# start: ' asked', next:  the
# start: ' former', next: ,
# start: 'itter', next: ,
# start: 'ript', next: ,
# start: ' close', next: ,
# start: ' pract', next: ,
# start: ' York', next: ,
# start: ' getting', next: ,
# start: ' across', next: ,
# start: ' comb', next: ,
# start: ' believe', next: ,
# start: ' z', next: ,
# start: ' toget', next: ,
# start: ' together', next: ,
# start: ' Cent', next: ,
# start: 'irc', next: ,
# start: ' individual', next: ,
# start: ' Mc', next: ,
# start: '27', next: ,
# start: 'isk', next: ,
# start: ' Eng', next: ,
# start: ' face', next:
#
# start: ' 24', next: ,
# start: ' value', next: ,
# start: ' area', next: ,
# start: 'ev', next: na
# start: ' writ', next: ,
# start: ' President', next: ,
# start: ' vot', next: ,
# start: ' key', next: ,
# start: ' mom', next: ,
# start: 'put', next: ,
# start: ' anything', next: ,
# start: ' experience', next: ,
# start: 'attle', next:
#
# start: ' mind', next: ,
# start: 'aff', next: airs
# start: 'omm', next: ,
# start: ' future', next: ,
# start: 'ged', next: ,
# start: ' cut', next: ,
# start: ' tot', next: ,
# start: 'itch', next: ,
# start: ' video', next: ,
# start: ' investig', next: ,
# start: ' net', next: ,
# start: ' My', next: ,
# start: 'rict', next: ,
# start: 'ien', next: ,
# start: '.)', next: :
# start: ' impro', next:
#
# start: 'though', next:
#
# start: 'wards', next: :
# start: ' connect', next: ,
# start: ' Med', next: ,
# start: 'selves', next: ,
# start: 'ensive', next: ,
# start: 'mb', next: ,
# start: 'ober', next: ,
# start: 'ators', next: ,
# start: 'An', next: ,
# start: ' 50', next: ,
# start: ' redu', next: ,
# start: 'resent', next: ost
# start: ' above', next: ,
# start: ' fre', next: ,
# start: ' Europe', next: ,
# start: 'sw', next: orn
# start: ' amount', next: ,
# start: ' App', next: ,
# start: ' either', next:
#
# start: ' milit', next: iam
# start: ' anal', next: ,
# start: ' fail', next: ,
# start: ' En', next: ns
# start: 'ales', next: ,
# start: ' special', next:
#
# start: ' black', next:  the
# start: 'IT', next: ,
# start: 'cher', next:
#
# start: ' looking', next: ,
# start: ' fire', next: ,
# start: 'yn', next: ,
# start: ' almost', next: ,
# start: 'oon', next: ,
# start: ' study', next: ,
# start: ' miss', next: ,
# start: 'ches', next: ,
# start: 'rown', next: ,
# start: ' tre', next: ,
# start: ' community', next: ,
# start: ' media', next: ,
# start: ' food', next: ,
# start: ' comes', next: ,
# start: ' University', next: ok
# start: ' single', next:
#
# start: 'What', next: ,
# start: 'uly', next: ,
# start: ' half', next:  the
# start: 'ague', next: ,
# start: 'hod', next: ,
# start: ' Republic', next: ,
# start: ' started', next: ,
# start: ' quick', next: ,
# start: 'oto', next: ,
# start: 'book', next: ,
# start: ' issue', next: ,
# start: 'itor', next: ,
# start: ' else', next: ,
# start: ' consider', next: ,
# start: '26', next: ,
# start: 'rodu', next: ,
# ...
# start: ' Saying', next: ,
# start: 'DERR', next: ,
# start: 'itone', next: ,
# start: 'Collins', next: ,
# start: 'Bound', next: ,
# start: ' bolted', next: ,
# start: ' DMCA', next: ,
# start: '953', next: ,
# start: ' uniqueness', next: ,
# start: ' epigen', next: :
# start: 'unci', next: ,
# start: 'antam', next: ,
# start: ' reckoning', next: ,
# start: 'chairs', next: ,
# start: 'OGR', next: ,
# start: ' Senegal', next: ,
# start: ' 1862', next: ,
# start: 'relevant', next: ,
# start: ' ¯', next:  the
# start: ' pharmacies', next: ,
# start: ' Geral', next: ,
# start: 'vier', next: ,
# start: 'Yan', next: EN
# start: 'ORPG', next: ,
# start: ' rabid', next: ,
# start: 'bending', next: ,
# start: ' UNITED', next: ,
# start: ' 465', next: ,
# start: 'Assembly', next: ,
# start: ' weep', next: ov
# start: ' behest', next: ,
# start: ' Mothers', next: ,
# start: ' Jace', next: ,
# start: 'hid', next: ,
# start: ' whirlwind', next: O
# start: ' UNIVERS', next: ,
# start: ' utopian', next: ov
# start: ' kidnap', next: ,
# start: 'Philipp', next: ,
# start: 'Kin', next: ,
# start: '893', next: ,
# start: ' livestream', next: ,
# start: ' MISS', next: EN
# start: ' subversive', next: ,
# start: ' Techniques', next: ,
# start: ' JUSTICE', next: ,
# start: ' BASE', next: ,
# start: ' 387', next: ,
# start: ' assailants', next: ,
# start: ' Hardcore', next: ,
# start: ' sprinkled', next: ,
# start: ' Pse', next: ,
# start: '�', next: ,
# start: 'printed', next: IO
# start: ' Hau', next: ,
# start: 'ORGE', next: ,
# start: ' TOUR', next: ,
# start: ' laced', next: :
# start: ' itch', next: ,
# start: 'Giving', next: ,
# start: ' ported', next: ,
# start: '781', next: ,
# start: '////////////////////////////////', next: ,
# start: 'breeding', next: ,
# start: ' logger', next: ,
# start: ' HOL', next: ,
# start: 'innie', next: ,
# start: 'Firstly', next: ,
# start: ' embryonic', next: ,
# start: ' delegated', next: ,
# start: 'pai', next: ,
# start: 'OIL', next: ,
# start: ' centrally', next: ,
# start: ' Rx', next:  the
# start: ' Scouting', next: ,
# start: 'Dutch', next: ,
# start: ' hereditary', next: ov
# start: ' Cruiser', next: ,
# start: 'sat', next:  the
# start: '529', next: ,
# start: ' Marriott', next: ,
# start: 'othermal', next: ,
# start: ' prohibitions', next: ,
# start: 'Earn', next: ,
# start: ' Stab', next: ,
# start: ' Colleges', next: ,
# start: ' Belief', next: ,
# start: 'stretched', next: ,
# start: ' LH', next: ,
# start: ' EntityItem', next: ,
# start: 'CIA', next: :
# start: ' unrem', next: ,
# start: ' laureate', next: ,
# start: ' denominations', next: ,
# start: 'summary', next: ,
# start: 'hler', next: ,
# start: 'Spect', next: ,
# start: ' Klaus', next: ,
# start: ' Beans', next: ,
# start: ' insur', next: ,
# start: ' PAX', next: ,
# start: ' fielder', next: ,
# start: ' Vet', next: ,
# start: ' Sparrow', next: ,
# start: 'zie', next: ,
# start: ' SQ', next: ,
# start: ' Mondays', next: ,
# start: ' Offline', next: ,
# start: ' Lerner', next: ,
# start: ' Extensions', next: 't
# start: 'Ireland', next: ,
# start: ' patronage', next: ,
# start: ' contrasted', next: ,
# start: ' Mania', next: ,
# start: 'hirt', next: ,
# start: 'Moscow', next: ,
# start: ' condemns', next: ,
# start: ' Ange', next: ,
# start: ' composing', next: ,
# start: ' Pepe', next: ,
# start: ' Paddock', next: ,
# start: ' heterogeneity', next: ,
# start: ' ideologically', next: :
# start: ' fishes', next: ,
# start: ' cursing', next: ,
# start: ' Rutherford', next: ,
# start: ' Floating', next: ,
# start: ' Amelia', next: ,
# start: 'Tea', next: ,
# start: 'Synopsis', next: ,
# start: ' stunts', next: ,
# start: ' bead', next: ,
# start: ' stocking', next: ,
# start: ' MILL', next: ,
# start: 'obook', next:
#
# start: 'massive', next: ,
# start: '\<', next: ,
# start: ' hump', next: ,
# start: ' Preferences', next: ,
# start: 'EngineDebug', next: ,
# start: 'geist', next: ,
# start: ' Nieto', next: er
# start: 'omever', next: ,
# start: 'ishy', next: ,
# start: 'evaluate', next: ,
# start: 'colonial', next: ,
# start: 'Alternative', next: ,
# start: ' GoPro', next: ,
# start: ' Vortex', next: ,
# start: ' NETWORK', next: ,
# start: 'ansky', next: ,
# start: 'Secure', next: ,
# start: ' Thrust', next: ,
# start: 'Snake', next: ,
# start: ' parcels', next: ,
# start: ' samurai', next: ,
# start: ' actresses', next: ,
# start: 'Nap', next: oleon
# start: 'MF', next: ,
# start: 'iferation', next: ,
# start: 'Beer', next: ,
# start: '523', next: ,
# start: ' Ily', next: ,
# start: 'ointment', next: ,
# start: 'Ping', next: ,
# start: ' striped', next: ,
# start: ' Mellon', next: ,
# start: 'ossession', next: ,
# start: ' neutron', next: ,
# start: 'endium', next: ,
# start: ' aph', next: :
# start: ' Flavoring', next: IO
# start: ' 383', next: ,
# start: ' responsiveness', next:  the
# start: ' Jindal', next: ,
# start: ' Hitchcock', next: ,
# start: 'Denver', next: ,
# start: ' DRAGON', next: ,
# start: 'smanship', next: ,
# start: ' Dupl', next: ,
# start: ' sly', next: ,
# start: ' webcam', next: ,
# start: ' Twain', next: ,
# start: ' Darling', next: :
# start: 'iliate', next: ,
# start: 'consumer', next:  to
# start: 'DIT', next: A
# start: ' namesake', next: ,
# start: ' unorthodox', next: ,
# start: ' funer', next: ,
# start: ' PLoS', next: ,
# start: ' CONTROL', next: ,
# start: 'ozyg', next: ,
# start: 'oglobin', next: ,
# start: 'FACE', next: ,
# start: 'ERG', next: ,
# start: ' Dia', next: ,
# start: ' Fiesta', next: ,
# start: 'cele', next: ,
# start: '034', next: ,
# start: ' enclave', next: ,
# start: '▬▬', next: ,
# start: 'onement', next: ,
# start: 'alist', next: ,
# start: 'Mand', next: ,
# start: ' homegrown', next: ,
# start: ' Fancy', next:
#
# start: ' conceptions', next: ,
# start: ' Contains', next: ,
# start: 'ureen', next: ,
# start: ' reiterate', next: ,
# start: ' meager', next: ,
# start: ' installments', next: ,
# start: 'Spawn', next: ,
# start: '627', next: ,
# start: ' photoc', next: ,
# start: ' Cabrera', next: ,
# start: ' Rosenthal', next:  the
# start: ' Lansing', next: ,
# start: 'isner', next: ,
# start: ' invests', next: ,
# start: ' UFOs', next: ,
# start: 'EXP', next: T
# start: 'Hardware', next: ,
# start: ' tragically', next: ,
# start: ' concedes', next: ,
# start: 'ieft', next: ,
# start: 'cham', next: ,
# start: 'borgh', next: ,
# start: ' Schr', next: ,
# start: ' Melanie', next: ,
# start: ' Hoy', next: ,
# start: ' visitation', next: ,
# start: ' idiosyncr', next: ,
# start: ' fractions', next: ,
# start: ' foreskin', next: ,
# start: 'obos', next: ,
# start: ' poaching', next: ,
# start: ' VIEW', next: ,
# start: ' stimulates', next: ,
# start: ' Gork', next: ,
# start: 'canon', next: ,
# start: 'MIC', next: ,
# start: ' Nemesis', next: ,
# start: ' Indra', next: ,
# start: ' DMV', next: ,
# start: ' 529', next: ,
# start: ' inspecting', next: ,
# start: ' grandma', next: ,
# start: ' Whedon', next: ,
# start: ' Shant', next: ,
# start: ' Purg', next: ,
# start: 'ikan', next: ,
# start: ' Teg', next: ,
# start: ' CLR', next: ,
# start: 'zac', next: ,
# start: 'Victoria', next: ,
# start: ' Verify', next: ,
# start: 'ionics', next: ,
# start: ' partying', next: ,
# start: ' Mou', next: ,
# start: 'colour', next: ,
# start: ' testimonies', next: ,
# start: 'lations', next: ,
# start: ' pressuring', next: ,
# start: 'hiro', next: ,
# start: 'acers', next: ,
# start: ' fid', next: ,
# start: 'angler', next: ,
# start: ' CSI', next: ,
# start: ' hereafter', next: ,
# start: ' dissidents', next: ,
# start: 'reporting', next: ,
# start: 'iphany', next: ,
# start: 'chev', next: ,
# start: ' solitude', next: ,
# start: ' lobe', next: ,
# start: ' indis', next: EN
# start: ' credential', next: ,
# start: 'recent', next: ,
# start: 'adult', next: ,
# start: ' Nirvana', next: ,
# start: ' Franchise', next: ,
# start: 'Layer', next: ,
# start: 'Hyp', next: ,
# start: ' Berkshire', next: ,
# start: ' wills', next: ,
# start: 'tif', next: ,
# start: ' totem', next: ,
# start: ' Judah', next: ,
# start: 'repair', next: ,
# start: 'Instant', next: ,
# start: '548', next: ,
# start: ' embassies', next: ,
# start: ' bottleneck', next: ,
# start: ' bount', next: eous
# start: ' typew', next: ,
# start: ' Alvin', next: ,
# start: 'jing', next: ,
# start: 'imilar', next: ,
# start: 'Rush', next: :
# start: ' brim', next: ,
# start: ' HELP', next: ,
# start: 'Aim', next: ,
# start: ']'', next: ,
# start: ' passively', next: ,
# start: ' bounded', next: ,
# start: ' Rated', next: ,
# start: ' criminality', next: ,
# start: ' biomark', next: ,
# start: ' dispatcher', next: ,
# start: ' Towards', next: ,
# start: ' +++', next: ,
# start: 'righteous', next: ,
# start: 'frog', next: ,
# start: ' Panc', next: ,
# start: 'Carter', next: ,
# start: '032', next: ,
# start: '機', next: ,
# start: ' ultraviolet', next: :
# start: ' Licensed', next:
#
# start: ' Tata', next: ,
# start: ' Blessing', next: ,
# start: ' GAM', next: ,
# start: ' chemically', next: ,
# start: ' Seaf', next:  the
# start: ' RELE', next: ,
# start: ' Mercenary', next: :
# start: 'capitalist', next: ,
# start: ' formulations', next: ikh
# start: ' annihilation', next: ,
# start: ' Verb', next: ,
# start: ' Argon', next: ,
# start: ' unloaded', next:
#
# start: ' morphed', next: ,
# start: ' conquering', next:  the
# start: 'backer', next:
#
# start: 'IELD', next: ,
# start: ' thefts', next: ,
# start: ' frontrunner', next: ,
# start: ' Royale', next: ,
# start: ' Fundamental', next: ,
# start: 'elight', next: ,
# start: 'Chip', next: ,
# start: 'necessary', next: ,
# start: 'ayn', next: ,
# start: ' Slip', next: :
# start: ' 448', next: ,
# start: 'cerned', next: ,
# start: 'Pause', next: ,
# start: ' shockingly', next: ,
# start: ' ABV', next: ,
# start: ' composure', next: ,
# start: '733', next: ,
# start: ' Motorsport', next: ,
# start: 'ahime', next: ,
# start: 'Murray', next: ,
# start: 'Mach', next: ,
# start: ' grids', next: ,
# start: ' debian', next: ,
# start: ' furthermore', next: ov
# start: ' dexterity', next:
#
# start: ' Collections', next: ,
# start: 'oslov', next: ,
# start: 'ilage', next: ,
# start: 'bj', next: ,
# start: ' Monteneg', next: ,
# start: ' strutConnector', next: ,
# start: ' massacres', next: ,
# start: ' briefs', next: EN
# start: 'fetched', next:
#
# start: 'uvian', next: ,
# start: 'olition', next: ,
# start: 'Failure', next: ,
# start: 'emonic', next: ,
# start: ' flared', next: ,
# start: ' claimant', next: ,
# start: ' cures', next: ,
# start: ' giveaways', next: ,
# start: ' Substance', next: ,
# start: 'alions', next: ,
# start: ' cringe', next: ,
# start: ' Kul', next: ,
# start: ' aristocracy', next: ,
# start: ' Ulster', next: ,
# start: 'olated', next: ,
# start: 'housing', next: ,
# start: ' MIS', next: ,
# start: ' glared', next: ,
# start: ' Wilhelm', next: ,
# start: 'needs', next: ,
# start: 'lambda', next: ,
# start: 'builders', next: ,
# start: ' VIS', next: ,
# start: ' radiator', next: ,
# start: ' Ghostbusters', next: ,
# start: ' 436', next: ok
# start: 'actual', next: ,
# start: ' herds', next: ,
# start: 'ça', next: ,
# start: 'watching', next: ,
# start: ' countering', next: ,
# start: 'Charge', next: ,
# start: ' charred', next: ,
# start: ' warheads', next: ,
# start: ' iodine', next: ,
# start: ' Macy', next: ,
# start: '041', next: ,
# start: ' departures', next: ,
# start: ' Sins', next: ,
# start: ' dyed', next: ,
# start: ' Concepts', next: ,
# start: 'gado', next:
#
# start: '713', next: ,
# start: ' quotations', next: ,
# start: ' gist', next: ON
# start: ' Christy', next: ,
# start: ' antigen', next: ,
# start: ' Hemp', next: ,
# start: ' Drawn', next: ,
# start: ' Barg', next: ,
# start: 'ezvous', next: :
# start: ' paternity', next: ,
# start: ' ardu', next: ,
# start: ' Anchorage', next: ,
# start: ' Rik', next: ,
# start: ' overloaded', next: ,
# start: ' Username', next: ,
# start: ' Tammy', next: ,
# start: ' Nau', next: ,
# start: ' Cellular', next: ,
# start: ' waning', next: ,
# start: ' rodent', next: ,
# start: ' Worcester', next: ,
# start: 'ilts', next: :
# start: ' Tad', next: :
# start: ' dwellings', next: ,
# start: ' bullish', next: ,
# start: '431', next: ,
# start: ' retaliate', next: ,
# start: ' migraine', next: ,
# start: ' Chevron', next: ,
# start: 'CHECK', next: ,
# start: ' donkey', next: ,
# start: 'crim', next: ,
# start: 'SPA', next: ,
# start: ' Analog', next: ,
# start: ' marquee', next: ,
# start: ' Haas', next: ,
# start: 'Bir', next: ,
# start: ' GDDR', next: ,
# start: ' Downloads', next: ,
# start: ' willpower', next: ,
# start: ' Forth', next: ,
# start: ' Recorded', next: ,
# start: ' impossibility', next: olute
# start: ' Logged', next: ,
# start: ' Franks', next: ,
# start: ' Ratt', next: ,
# start: 'initions', next: ,
# start: ' cleaners', next: ,
# start: ' sorely', next: ,
# start: ' flickering', next: ,
# start: ' Examination', next: ,
# start: 'catching', next: ,
# start: 'alloween', next: ,
# start: 'Msg', next: ,
# start: ' dunno', next: ,
# start: 'Fa', next: ,
# start: ' dysph', next: ,
# start: 'crazy', next: ,
# start: '.''.', next: ,
# start: ' mainline', next: ,
# start: ' cs', next: ,
# start: ' ptr', next: ,
# start: ' Wally', next: ,
# start: 'igun', next: ,
# start: '951', next: ,
# start: ' Bigfoot', next: ,
# start: 'fights', next: ,
# start: ' retrieving', next: ,
# start: 'Jr', next: ,
# start: ' duplication', next: ,
# start: ' Explan', next: ,
# start: ' relational', next: ,
# start: ' quaint', next: ,
# start: ' biscuits', next: ,
# start: ' ado', next: ,
# start: ' shudder', next: ,
# start: ' antidote', next: ,
# start: 'blooded', next: ,
# start: 'ksh', next: ,
# start: ' sauces', next: ,
# start: ' reinvest', next: ,
# start: ' dispensary', next: ,
# start: ' Diver', next: ,
# start: ' 9000', next: ,
# start: 'student', next: ,
# start: ' insepar', next: ,
# start: 'escap', next: ,
# start: ' toddlers', next: ,
# start: ' GPIO', next: ,
# start: ' Assignment', next: ,
# start: 'headers', next: ,
# start: ' lackluster', next: ,
# start: ' aback', next: ,
# start: '956', next: ,
# start: ' toolbar', next: EN
# start: '745', next: O
# start: ' oust', next: ,
# start: ' contemplation', next: ,
# start: ' PRESIDENT', next: ,
# start: ' 458', next: ,
# start: '======', next:
#
# start: ' guaranteeing', next: ,
# start: ' Heist', next: ,
# start: ' Cannes', next: ,
# start: '��', next: ,
# start: ' collaborator', next: ,
# start: ' Amp', next: ,
# start: ' gou', next: ,
# start: ' SHALL', next: ,
# start: 'stories', next: ,
# start: '783', next: ,
# start: ' mobilized', next: ,
# start: ' brood', next: ,
# start: ' LU', next: ,
# start: ' �', next: ,
# start: ' refin', next: ,
# start: ' Anthropology', next: ,
# start: 'vind', next: ,
# start: 'illi', next: ,
# start: ' warranties', next: ,
# start: ' Babel', next: ,
# start: ' swath', next: ,
# start: ' caches', next: ,
# start: ' antagonists', next: ,
# start: 'artifacts', next: ,
# start: ' hotly', next: ,
# start: ' Starts', next: ,
# start: ' Gö', next: ,
# start: 'zag', next: ,
# start: '!!!!!', next: ,
# start: ' scourge', next: ,
# start: ' conspiring', next:
#
# start: 'ruits', next: ,
# start: 'reverse', next: ,
# start: ' Sheen', next: ,
# start: ' Jesuit', next: ,
# start: ' Giovanni', next: ,
# start: 'adies', next: ,
# start: ' buttocks', next: AR
# start: 'earcher', next: ,
# start: 'acan', next: ,
# start: ' volleyball', next: ,
# start: ' shrouded', next:
#
# start: ' scoreboard', next: ,
# start: 'bats', next: ,
# start: ' IPM', next: ,
# start: ' asses', next: ,
# start: ' deregulation', next: ,
# start: ' Telegram', next: ,
# start: ' Reboot', next: ,
# start: ' 7000', next: ,
# start: ' Canary', next: ,
# start: ' kernels', next: ,
# start: ' François', next: ,
# start: ' Duff', next: ,
# start: ' Pon', next: ,
# start: ' Leica', next: ,
# start: ' Garmin', next: ,
# start: ' orphans', next: ,
# start: ' Claudia', next: ,
# start: ' calendars', next: ,
# start: ' Leilan', next: ,
# start: 'ento', next: ,
# start: 'Rocket', next: ,
# start: ' brunch', next: ,
# start: ' Hawking', next: ,
# start: 'ainers', next:
#
# start: ' sensibilities', next: ,
# start: ' kW', next: ,
# start: ' Kand', next: ,
# start: ' reclaimed', next:  said
# start: ' interestingly', next: ,
# start: 'ש', next: ,
# start: 'romy', next: ,
# start: 'JM', next: ,
# start: ' Enhancement', next: ,
# start: 'bush', next: ,
# start: 'Skip', next: ,
# start: ' rappers', next: ,
# start: ' gazing', next: ,
# start: 'pedia', next: ,
# start: 'athlon', next: ,
# start: 'Revolution', next: ,
# start: ' snipers', next: ,
# start: ' reverted', next: ,
# start: ' conglomerate', next: ,
# start: 'Terry', next: ,
# start: '794', next: ,
# start: ' harsher', next: ,
# start: ' desolate', next: ,
# start: ' Hitman', next: ,
# start: 'Commission', next: ,
# start: ' (/', next: ,
# start: '…."', next:  the
# start: 'Compar', next: ,
# start: ' amplification', next: ,
# start: 'ominated', next: ,
# start: ' regress', next: ,
# start: ' Collider', next: ,
# start: ' informants', next: ,
# start: ' gazed', next: ,
# start: '<|endoftext|>', next: ,

# %%
def sample_from_model(model, start_text, encoder, max_new_tokens, temperature=1.0, top_k=50):
    model.eval()
    model.to(device)

    start_tokens = encoder.encode(start_text)
    idx = torch.tensor(start_tokens, dtype=torch.long, device=device)
    if idx.dim() == 1:
        idx = idx.unsqueeze(0) 

    for _ in range(max_new_tokens):
        logits = model(idx)
        logits = logits[:, -1, :] 
        
        logits = logits / temperature

        if top_k is not None:
            top_logits, top_idx = torch.topk(logits, top_k, dim=-1)
            logits_filtered = torch.full_like(logits, float('-inf'))
            logits_filtered.scatter_(1, top_idx, top_logits)
            logits = logits_filtered

        probs = F.softmax(logits, dim=-1)
        next_idx = torch.multinomial(probs, num_samples=1)
        
        idx = torch.cat((idx, next_idx), dim=1)
        
    generated_tokens = idx.squeeze(0).cpu().numpy()
    return encoder.decode(generated_tokens)

# %%
start_prompt = "the meaning of life is"

generated_text = sample_from_model(
    model=model,
    start_text=start_prompt,
    encoder=enc,
    max_new_tokens=100,
    temperature=0.8,
    top_k=40
)

print("\n--- Generated Text ---")
print(generated_text)
# Out:
# --- Generated Text ---
# the meaning of life is to me
#
#
#
#
#
#
# B
#
#
# killed.
# And then of
#
# POMPEYORK
# prepared. They will be said the that he had and the
# And his
#
#
#
#
#
# And to his to his
#
# And a great.
